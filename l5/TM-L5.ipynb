# %% [markdown]
# # L5: Information extraction

# %% [markdown]
# Information extraction (IE) is the task of identifying named entities and semantic relations between these entities in text data. In this lab we will focus on two sub-tasks in IE, **named entity recognition** (identifying mentions of entities) and **entity linking** (matching these mentions to entities in a knowledge base).

# %% [markdown]
# **Reminder about our [Rules for hand-in assignments](https://www.ida.liu.se/~TDDE16/exam.en.shtml#handins) and the [Policy on cheating and plagiarism](https://www.ida.liu.se/~TDDE16/exam.en.shtml#cheating)**

# %% [markdown]
# We start by loading spaCy:

# %%
import spacy

nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# The data that we will be using has been tokenized following the conventions of the [Penn Treebank](ftp://ftp.cis.upenn.edu/pub/treebank/public_html/tokenization.html), and we need to prevent spaCy from using its own tokenizer on top of this. We therefore override spaCy&rsquo;s tokenizer with one that simply splits on space.

# %%
from spacy.tokens import Doc

class WhitespaceTokenizer(object):
    def __init__(self, vocab):
        self.vocab = vocab

    def __call__(self, text):
        return Doc(self.vocab, words=text.split(' '))

nlp.tokenizer = WhitespaceTokenizer(nlp.vocab)

# %% [markdown]
# ## Data set

# %% [markdown]
# The main data set for this lab is a collection of news wire articles in which mentions of named entities have been annotated with page names from the [English Wikipedia](https://en.wikipedia.org/wiki/). The next code cell loads the training and the development parts of the data into Pandas data frames.

# %%
import bz2
import csv
import pandas as pd

with bz2.open('ner-train.tsv.bz2', 'rt', encoding = 'cp850') as source:
    df_train = pd.read_csv(source, sep='\t', quoting=csv.QUOTE_NONE)

with bz2.open('ner-dev.tsv.bz2', 'rt', encoding = 'cp850') as source:
    df_dev = pd.read_csv(source, sep='\t', quoting=csv.QUOTE_NONE)

# %% [markdown]
# Each row in these two data frames corresponds to one mention of a named entity and has five columns:
#
# 1. a unique identifier for the sentence containing the entity mention
# 2. the pre-tokenized sentence, with tokens separated by spaces
# 3. the start position of the token span containing the entity mention
# 4. the end position of the token span (exclusive, as in Python list indexing)
# 5. the entity label; either a Wikipedia page name or the generic label `--NME--`
#
# The following cell prints the first five samples from the training data:

# %%
df_train.head()
# Out:
#   sentence_id                                          sentence  beg  end  \
# 0    0000-000  EU rejects German call to boycott British lamb .    0    1
# 1    0000-000  EU rejects German call to boycott British lamb .    2    3
# 2    0000-000  EU rejects German call to boycott British lamb .    6    7
# 3    0000-001                                   Peter Blackburn    0    2
# 4    0000-002                               BRUSSELS 1996-08-22    0    1
#
#             label
# 0         --NME--
# 1         Germany
# 2  United_Kingdom
# 3         --NME--
# 4        Brussels

# %% [markdown]
# In this sample, we see that the first sentence is annotated with three entity mentions:
#
# * the span 0–1 &lsquo;EU&rsquo; is annotated as a mention but only labelled with the generic `--NME--`
# * the span 2–3 &lsquo;German&rsquo; is annotated with the page [Germany](http://en.wikipedia.org/wiki/Germany)
# * the span 6–7 &lsquo;British&rsquo; is annotated with the page [United_Kingdom](http://en.wikipedia.org/wiki/United_Kingdom)

# %% [markdown]
# ## Problem 1: Evaluation measures

# %% [markdown]
# To warm up, we ask you to write code to print the three measures that you will be using for evaluation:

# %%
import numpy as np

def evaluation_report(gold, pred):
    """Print precision, recall, and F1 score.
    
    Args:
        gold: The set with the gold-standard values.
        pred: The set with the predicted values.
    
    Returns:
        Nothing, but prints the precision, recall, and F1 values computed
        based on the specified sets.
    """
    prec = len(gold & pred)/len(pred)
    rec = len(gold & pred)/len(gold)
    f1 = 2 *(prec * rec) / (prec + rec)
    print("precision:" ,prec , ", recall: " , rec , ", f1: " , f1)
    pass

# %% [markdown]
# To test your code, you can run the following cell:

# %%
evaluation_report(set(range(3)), set(range(5)))
# Out:
# precision: 0.6 , recall:  1.0 , f1:  0.7499999999999999

# %% [markdown]
# This should give you a precision of 60%, a recall of 100%, and an F1-value of 75%.

# %% [markdown]
# ## Problem 2: Span recognition

# %% [markdown]
# One of the first tasks that an information extraction system has to solve is to locate and classify (mentions of) named entities, such as persons and organizations. Here we will tackle the simpler task of recognizing **spans** of tokens that contain an entity mention, without the actual entity label.
#
# The English language model in spaCy features a full-fledged [named entity recognizer](https://spacy.io/usage/linguistic-features#named-entities) that identifies a variety of entities, and can be updated with new entity types by the user. Your task in this problem is to evaluate the performance of this component when predicting entity spans in the development data.
#
# Start by implementing a generator function that yields the gold-standard spans in a given data frame.
#
# **Hint:** The Pandas method [`itertuples()`](https://pandas.pydata.org/pandas-docs/version/0.17.0/generated/pandas.DataFrame.itertuples.html) is useful when iterating over the rows in a DataFrame.

# %%
def gold_spans(df):
    """Yield the gold-standard mention spans in a data frame.

    Args:
        df: A data frame.

    Yields:
        The gold-standard mention spans in the specified data frame as
        triples consisting of the sentence id, start position, and end
        position of each span.
    """
    for i in df.itertuples():
        yield (i.sentence_id, i.beg, i.end)

# %% [markdown]
# To test your code, you can count the spans yielded by your function. When called on the development data, you should get a total of 5,917 unique triples. The first triple and the last triple should be
#
#     ('0946-000', 2, 3)
#     ('1161-010', 1, 3)

# %%
spans_dev_gold = set(gold_spans(df_dev))
print(len(spans_dev_gold))
# Out:
# 5917

# %% [markdown]
# Your next task is to write code that calls spaCy to predict the named entities in the development data, and to evaluate the accuracy of these predictions in terms of precision, recall, and F1. Print these scores using the function that you wrote for Problem&nbsp;1.

# %%
df = df_dev 
data = set()
for i in df.drop_duplicates('sentence_id').itertuples():
    doc = nlp(i.sentence)
    for ent in doc.ents:
        data.add((i.sentence_id, ent.start, ent.end))

# %%
evaluation_report(spans_dev_gold, data)
# Out:
# precision: 0.5383185017930668 , recall:  0.6849754943383471 , f1:  0.6028558679161089

# %% [markdown]
# ## Problem 3: Error analysis

# %% [markdown]
# As you were able to see in Problem&nbsp;2, the span accuracy of the named entity recognizer is far from perfect. In particular, only slightly more than half of the predicted spans are correct according to the gold standard. Your next task is to analyse this result in more detail.
#
# Here is a function that prints the false positives as well as the false negatives spans for a data frame, given a reference set of gold-standard spans and a candidate set of predicted spans.

# %%
from collections import defaultdict

def error_report(df, spans_gold, spans_pred):
    false_pos = defaultdict(list)
    for s, b, e in spans_pred - spans_gold:
        false_pos[s].append((b, e))
    false_neg = defaultdict(list)
    for s, b, e in spans_gold - spans_pred:
        false_neg[s].append((b, e))
    for row in df.drop_duplicates('sentence_id').itertuples():
        if row.sentence_id in false_pos or row.sentence_id in false_neg:
            print('Sentence:', row.sentence)
            for b, e in false_pos[row.sentence_id]:
                print('  FP:', ' '.join(row.sentence.split()[b:e]))
            for b, e in false_neg[row.sentence_id]:
                print('  FN:', ' '.join(row.sentence.split()[b:e]))

# %% [markdown]
# Use this function to inspect and analyse the errors that the automated prediction makes. Can you see any patterns? Base your analysis on the first 500 rows of the training data. Summarize your observations in a short text.

# %%
df = df_dev[:500]
spans_dev_gold = set(gold_spans(df))
data = set()
for i in df.drop_duplicates('sentence_id').itertuples():
    doc = nlp(i.sentence)
    for ent in doc.ents:
        data.add((i.sentence_id, ent.start, ent.end))

# %%
error_report(df, spans_dev_gold, data)
# Out:
# Sentence: CRICKET - LEICESTERSHIRE TAKE OVER AT TOP AFTER INNINGS VICTORY .
#   FN: LEICESTERSHIRE
# Sentence: West Indian all-rounder Phil Simmons took four for 38 on Friday as Leicestershire beat Somerset by an innings and 39 runs in two days to take over at the head of the county championship .
#   FP: four
#   FP: 39
#   FP: two days
#   FP: 38
#   FP: Friday
#   FN: Somerset
# Sentence: After bowling Somerset out for 83 on the opening morning at Grace Road , Leicestershire extended their first innings by 94 runs before being bowled out for 296 with England discard Andy Caddick taking three for 83 .
#   FP: 94
#   FP: 296
#   FP: three
#   FP: 83
#   FP: the opening morning
#   FP: first
#   FP: 83
# Sentence: Trailing by 213 , Somerset got a solid start to their second innings before Simmons stepped in to bundle them out for 174 .
#   FP: 213
#   FP: 174
#   FP: second
# Sentence: Essex , however , look certain to regain their top spot after Nasser Hussain and Peter Such gave them a firm grip on their match against Yorkshire at Headingley .
#   FN: Headingley
# Sentence: Hussain , considered surplus to England 's one-day requirements , struck 158 , his first championship century of the season , as Essex reached 372 and took a first innings lead of 82 .
#   FP: first
#   FP: 158
#   FP: 372
#   FP: 82
#   FP: first championship century of the season
#   FN: Hussain
# Sentence: By the close Yorkshire had turned that into a 37-run advantage but off-spinner Such had scuttled their hopes , taking four for 24 in 48 balls and leaving them hanging on 119 for five and praying for rain .
#   FP: five
#   FP: four
#   FP: 24
#   FP: 37-run
#   FP: 48
#   FP: 119
#   FN: Such
# Sentence: At the Oval , Surrey captain Chris Lewis , another man dumped by England , continued to silence his critics as he followed his four for 45 on Thursday with 80 not out on Friday in the match against Warwickshire .
#   FP: 45
#   FP: Thursday
#   FP: Friday
#   FP: four
#   FP: 80
#   FN: Oval
# Sentence: He was well backed by England hopeful Mark Butcher who made 70 as Surrey closed on 429 for seven , a lead of 234 .
#   FP: 429
#   FP: 234
#   FP: 70
#   FP: seven
# Sentence: Derbyshire kept up the hunt for their first championship title since 1936 by reducing Worcestershire to 133 for five in their second innings , still 100 runs away from avoiding an innings defeat .
#   FP: 1936
#   FP: 100
#   FP: first
#   FP: second
#   FP: five
#   FP: 133
#   FN: Derbyshire
# Sentence: Australian Tom Moody took six for 82 but Chris Adams , 123 , and Tim O'Gorman , 109 , took Derbyshire to 471 and a first innings lead of 233 .
#   FP: 109
#   FP: 123
#   FP: first
#   FP: 82
#   FP: 471
#   FP: six
#   FP: 233
#   FP: Australian Tom Moody
#   FN: Australian
#   FN: Tom Moody
# Sentence: After the frustration of seeing the opening day of their match badly affected by the weather , Kent stepped up a gear to dismiss Nottinghamshire for 214 .
#   FP: 214
# Sentence: They were held up by a gritty 84 from Paul Johnson but ex-England fast bowler Martin McCague took four for 55 .
#   FP: four
#   FP: 55
#   FP: 84
#   FN: ex-England
# Sentence: By stumps Kent had reached 108 for three .
#   FP: 108
#   FP: three
# Sentence: CRICKET - ENGLISH COUNTY CHAMPIONSHIP SCORES .
#   FP: CRICKET - ENGLISH COUNTY CHAMPIONSHIP SCORES
#   FN: ENGLISH COUNTY CHAMPIONSHIP
# Sentence: Result and close of play scores in English county championship matches on Friday :
#   FP: Friday
# Sentence: Leicester : Leicestershire beat Somerset by an innings and 39 runs .
#   FP: 39
#   FN: Leicester
#   FN: Somerset
# Sentence: Somerset 83 and 174 ( P. Simmons 4-38 ) , Leicestershire 296 .
#   FP: 83
#   FP: 4-38
#   FP: Leicestershire 296
#   FP: 174
#   FN: Leicestershire
#   FN: P. Simmons
#   FN: Somerset
# Sentence: Leicestershire 22 points , Somerset 4 .
#   FP: 22
#   FP: Somerset 4
#   FN: Somerset
#   FN: Leicestershire
# Sentence: Chester-le-Street : Glamorgan 259 and 207 ( A. Dale 69 , H. Morris 69 ; D. Blenkiron 4-43 ) , Durham 114 ( S. Watkin 4-28 ) and 81-3 .
#   FP: 81-3
#   FP: 259
#   FP: 207
#   FP: A. Dale 69
#   FP: Durham 114
#   FP: S. Watkin 4-28
#   FP: H. Morris 69
#   FP: D.
#   FN: A. Dale
#   FN: H. Morris
#   FN: Glamorgan
#   FN: S. Watkin
#   FN: D. Blenkiron
#   FN: Durham
#   FN: Chester-le-Street
# Sentence: Tunbridge Wells : Nottinghamshire 214 ( P. Johnson 84 ; M. McCague 4-55 ) , Kent 108-3 .
#   FP: Kent 108-3
#   FP: M. McCague 4-55
#   FN: Nottinghamshire
#   FN: Kent
#   FN: M. McCague
#   FN: P. Johnson
# Sentence: London ( The Oval ) : Warwickshire 195 , Surrey 429-7 ( C. Lewis 80 not out , M. Butcher 70 , G. Kersey 63 , J. Ratcliffe 63 , D. Bicknell 55 ) .
#   FP: J. Ratcliffe 63
#   FP: D. Bicknell 55
#   FP: G. Kersey 63
#   FP: 195
#   FP: M. Butcher 70
#   FP: Surrey 429-7
#   FP: C. Lewis 80
#   FN: D. Bicknell
#   FN: The Oval
#   FN: C. Lewis
#   FN: Warwickshire
#   FN: M. Butcher
#   FN: Surrey
#   FN: J. Ratcliffe
#   FN: G. Kersey
# Sentence: Hove : Sussex 363 ( W. Athey 111 , V. Drakes 52 ; I. Austin 4-37 ) , Lancashire 197-8 ( W. Hegg 54 )
#   FP: Lancashire 197-8
#   FP: I. Austin 4-37
#   FP: 54
#   FP: 52
#   FN: W. Hegg
#   FN: Lancashire
#   FN: I. Austin
#   FN: W. Athey
#   FN: Hove
#   FN: Sussex
# Sentence: Portsmouth : Middlesex 199 and 426 ( J. Pooley 111 , M. Ramprakash 108 , M. Gatting 83 ) , Hampshire 232 and 109-5 .
#   FP: 232
#   FP: 109-5
#   FP: 199
#   FP: J. Pooley 111
#   FP: 426
#   FP: M. Gatting 83
#   FP: M. Ramprakash 108
#   FN: J. Pooley
#   FN: M. Ramprakash
#   FN: M. Gatting
#   FN: Portsmouth
# Sentence: Chesterfield : Worcestershire 238 and 133-5 , Derbyshire 471 ( J. Adams 123 , T.O'Gorman 109 not out , K. Barnett 87 ; T. Moody 6-82 )
#   FP: 109
#   FP: K. Barnett 87
#   FP: 238
#   FP: 133-5
#   FP: T. Moody 6-82
#   FP: Derbyshire 471
#   FP: J. Adams 123
#   FN: K. Barnett
#   FN: Chesterfield
#   FN: Derbyshire
#   FN: Worcestershire
#   FN: T. Moody
#   FN: T.O'Gorman
#   FN: J. Adams
# Sentence: Bristol : Gloucestershire 183 and 185-6 ( J. Russell 56 not out ) , Northamptonshire 190 ( K. Curran 52 ; A. Smith 5-68 ) .
#   FP: 190
#   FP: 183
#   FP: J. Russell 56
#   FP: A. Smith 5-68
#   FP: 185-6
#   FN: A. Smith
#   FN: Northamptonshire
#   FN: J. Russell
#   FN: K. Curran
#   FN: Gloucestershire
# Sentence: CRICKET - 1997 ASHES INTINERARY .
#   FN: ASHES
# Sentence: starting on May 13 next year , the Test and County Cricket Board
#   FP: County Cricket Board
#   FP: May 13 next year
#   FN: Test and County Cricket Board
# Sentence: Australia will also play three one-day internationals and
#   FP: three
# Sentence: English county sides and another against British Universities ,
#   FP: English county
#   FN: English
# Sentence: as well as one-day matches against the Minor Counties and
#   FN: Minor Counties
# Sentence: May 13 Arrive in London
#   FP: May 13
# Sentence: May 14 Practice at Lord 's
#   FP: May 14
#   FN: Lord 's
# Sentence: May 15 v Duke of Norfolk 's XI ( at Arundel )
#   FP: Norfolk
#   FP: May 15
#   FN: Duke of Norfolk 's XI
# Sentence: May 17 v Northampton
#   FP: May 17
#   FN: Northampton
# Sentence: May 18 v Worcestershire
#   FP: May 18
#   FN: Worcestershire
# Sentence: May 20 v Durham
#   FP: May 20
#   FN: Durham
# Sentence: May 22 First one-day international ( at Headingley ,
#   FP: May 22
#   FP: First
# Sentence: Leeds )
#   FN: Leeds
# Sentence: May 24 Second one-day international ( at The Oval ,
#   FP: one-day
#   FP: May 24 Second
#   FN: The Oval
# Sentence: May 25 Third one-day international ( at Lord 's , London )
#   FP: Third
#   FP: May 25
# Sentence: May 27-29 v Gloucestershire or Sussex or Surrey ( three
#   FP: three
#   FN: Gloucestershire
# Sentence: May 31 - June 2 v Derbyshire ( three days )
#   FP: three days
#   FP: May 31 - June 2 v Derbyshire
#   FN: Derbyshire
# Sentence: June 5-9 First test match ( at Edgbaston , Birmingham )
#   FP: June 5-9 First
# Sentence: June 14-16 v Leicestershire ( three days )
#   FP: June 14-16 v
#   FP: three days
#   FN: Leicestershire
# Sentence: June 19-23 Second test ( at Lord 's )
#   FP: Second
#   FP: June 19-23
#   FN: Lord 's
# Sentence: June 25-27 v British Universities ( at Oxford , three days )
#   FP: three days
#   FP: June 25-27
#   FP: v British Universities
#   FN: British Universities
# Sentence: June 28-30 v Hampshire ( three days )
#   FP: three days
#   FP: June 28-30 v Hampshire
#   FN: Hampshire
# Sentence: July 3-7 Third test ( at Old Trafford , Manchester )
#   FP: July
# Sentence: July 9 v Minor Counties XI
#   FP: July 9
#   FN: Minor Counties XI
# Sentence: July 12 v Scotland
#   FP: July 12
#   FN: Scotland
# Sentence: July 16-18 v Glamorgan ( three days )
#   FP: July 16-18 v Glamorgan ( three days
#   FN: Glamorgan
# Sentence: July 19-21 v Middlesex ( three days )
#   FP: three days
#   FP: July 19-21 v Middlesex
#   FN: Middlesex
# Sentence: July 24-28 Fourth test ( at Headingley )
#   FP: July 24-28 Fourth
# Sentence: August 1-4 v Somerset ( four days )
#   FP: four days
#   FP: August
#   FN: Somerset
# Sentence: August 7-11 Fifth test ( at Trent Bridge , Nottingham )
#   FP: August
#   FP: Fifth
# Sentence: August 16-18 v Kent ( three days )
#   FP: three days
#   FP: August
#   FN: Kent
# Sentence: August 21-25 Sixth test ( at The Oval , London ) .
#   FP: August 21-25 Sixth
# Sentence: SOCCER - SHEARER NAMED AS ENGLAND CAPTAIN .
#   FP: SOCCER - SHEARER NAMED AS ENGLAND CAPTAIN
#   FN: SHEARER
#   FN: ENGLAND
# Sentence: The world 's costliest footballer Alan Shearer was named as the new England captain on Friday .
#   FP: Friday
# Sentence: The 26-year-old , who joined Newcastle for 15 million pounds sterling ( $ 23.4 million ) , takes over from Tony Adams , who led the side during the European championship in June , and former captain David Platt .
#   FP: June
#   FP: 26-year-old
#   FP: $ 23.4 million
#   FP: 15 million pounds
# Sentence: Adams and Platt are both injured and will miss England 's opening World Cup qualifier against Moldova on Sunday .
#   FP: Sunday
# Sentence: " I 'm sure there wo n't be a problem , I 'm sure Alan is the man for the job , " Hoddle said .
#   FN: Hoddle
# Sentence: " There were three or four people who could have done it but when I spoke to Alan he was up for it and really wanted it .
#   FP: three or four
# Sentence: Shearer 's Euro 96 striking partner Teddy Sheringham withdrew from the squad with an injury on Friday .
#   FP: Friday
# Sentence: SOCCER - ROMANIA BEAT LITHUANIA IN UNDER-21 MATCH .
#   FP: SOCCER - ROMANIA BEAT LITHUANIA
#   FN: ROMANIA
#   FN: LITHUANIA
# Sentence: BUCHAREST 1996-08-30
#   FN: BUCHAREST
# Sentence: Romania beat Lithuania 2-1 ( halftime 1-1 ) in their European under-21 soccer match on Friday .
#   FP: Friday
#   FP: under-21
#   FP: 1-1
#   FP: Lithuania 2-1
#   FN: Lithuania
# Sentence: Romania - Cosmin Contra ( 31st ) , Mihai Tararache ( 75th )
#   FP: 75th
#   FP: 31st
#   FN: Cosmin Contra
# Sentence: Lithuania - Danius Gleveckas ( 13rd )
#   FN: Danius Gleveckas
# Sentence: SOCCER - ROTOR FANS LOCKED OUT AFTER VOLGOGRAD VIOLENCE .
#   FP: SOCCER - ROTOR FANS LOCKED OUT AFTER
#   FN: ROTOR
#   FN: VOLGOGRAD
# Sentence: MOSCOW 1996-08-30
#   FN: MOSCOW
# Sentence: Rotor Volgograd must play their next home game behind closed doors after fans hurled bottles and stones at Dynamo Moscow players during a 1-0 home defeat on Saturday that ended Rotor 's brief spell as league leaders .
#   FP: 1-0
#   FP: Saturday
#   FP: Volgograd
#   FN: Rotor Volgograd
# Sentence: The head of the Russian league 's disciplinary committee , Anatoly Gorokhovsky , said on Friday that Rotor would play Lada Togliatti to empty stands on September 3 .
#   FP: Friday
#   FP: September 3
#   FN: Rotor
# Sentence: The club , who put Manchester United out of last year 's UEFA Cup , were fined $ 1,000 .
#   FP: last year 's
#   FP: 1,000
# Sentence: Despite the defeat , Rotor are well placed with 11 games to play in the championship .
#   FP: 11
#   FN: Rotor
# Sentence: Lying three points behind Alania and two behind Dynamo Moscow , the Volgograd side have a game in hand over the leaders and two over the Moscow club .
#   FP: three
#   FP: two
#   FP: two
# Sentence: BOXING - PANAMA 'S ROBERTO DURAN FIGHTS THE SANDS OF TIME .
#   FP: BOXING - PANAMA 'S
#   FN: ROBERTO DURAN
#   FN: PANAMA
# Sentence: PANAMA CITY 1996-08-30
#   FP: PANAMA CITY 1996-08-30
#   FN: PANAMA CITY
# Sentence: Panamanian boxing legend Roberto " Hands of Stone " Duran climbs into the ring on Saturday in another age-defying attempt to sustain his long career .
#   FP: Saturday
#   FP: Duran
#   FP: Roberto " Hands of Stone "
#   FN: Roberto " Hands of Stone " Duran
# Sentence: Duran , 45 , takes on little-known Mexican Ariel Cruz , 30 , in a super middleweight non-title bout in Panama City .
#   FP: 45
#   FP: 30
# Sentence: The fight , Duran 's first on home soil for 10 years , is being billed here as the " Return of the Legend " and Duran still talks as if he was in his prime .
#   FP: first
#   FP: 10 years
#   FN: Return of the Legend
# Sentence: If he loses Saturday , it could devalue his position as one of the world 's great boxers , " Panamanian Boxing Association President Ramon Manzanares said .
#   FP: Panamanian Boxing Association
#   FP: one
#   FP: Saturday
#   FN: Panamanian
#   FN: Boxing Association
# Sentence: Duran , whose 97-12 record spans three decades , hopes a win in the 10-round bout will earn him a rematch against Puerto Rico 's Hector " Macho " Camacho .
#   FP: Puerto Rico 's
#   FP: 10-round
#   FP: three decades
#   FN: Puerto Rico
#   FN: Hector " Macho " Camacho
# Sentence: Camacho took a controversial points decision against the Panamanian in Atlantic City in June in a title fight .
#   FP: June
# Sentence: SQUASH - HONG KONG OPEN QUARTER-FINAL RESULTS .
#   FP: SQUASH - HONG KONG OPEN QUARTER-FINAL RESULTS
#   FN: HONG KONG OPEN
# Sentence: Quarter-final results in the Hong Kong Open on Friday ( prefix number denotes seeding ) : 1 - Jansher Khan ( Pakistan ) beat Mark Cairns ( England ) 15-10 15-6 15-7
#   FP: 1 - Jansher Khan
#   FP: Friday
#   FN: Hong Kong Open
#   FN: Jansher Khan
# Sentence: 4 - Peter Nicol ( Scotland ) beat 7 - Chris Walker ( England ) 15-8 15-13 13-15 15-9
#   FP: 15-8
#   FP: 4
#   FN: Chris Walker
# Sentence: 2 - Rodney Eyles ( Australia ) beat Derek Ryan ( Ireland ) 15-6 15-9 11-15 15-10 .
#   FP: 2
#   FP: 15-6 15-9 11-15 15-10
#   FN: Australia
#   FN: Rodney Eyles
# Sentence: SOCCER - RESULTS OF SOUTH KOREAN PRO-SOCCER GAMES .
#   FN: SOUTH KOREAN
# Sentence: Pohang 3 Ulsan 2 ( halftime 1-0 )
#   FP: 1-0
#   FP: Pohang 3 Ulsan 2
#   FN: Pohang
#   FN: Ulsan
# Sentence: Puchon 2 Chonbuk 1 ( halftime 1-1 )
#   FP: 1-1
#   FP: Puchon 2 Chonbuk 1
#   FN: Chonbuk
#   FN: Puchon
# Sentence: Puchon 3 1 0 6 1 10
#   FP: 6 1 10
#   FN: Puchon
# Sentence: Chonan 3 0 1 13 10 9
#   FP: 0 1 13
#   FP: 3
#   FN: Chonan
# Sentence: Pohang 2 1 1 11 10 7
#   FN: Pohang
# Sentence: Suwan 1 3 0 7 3 6
#   FP: 1 3
#   FP: 7 3 6
#   FN: Suwan
# Sentence: Ulsan 1 0 2 8 9 3
#   FN: Ulsan
# Sentence: Anyang 0 3 1 6 9 3
#   FP: Anyang 0 3
#   FN: Anyang
# Sentence: Chonnam 0 2 1 4 5 2
#   FN: Chonnam
# Sentence: Pusan 0 2 1 3 7 2
#   FN: Pusan
# Sentence: Chonbuk 0 0 3 3 7 0
#   FP: 0 3 3
#   FN: Chonbuk
# Sentence: BASEBALL - RESULTS OF S. KOREAN PROFESSIONAL GAMES .
#   FN: S. KOREAN
# Sentence: LG 2 OB 0
#   FN: OB
#   FN: LG
# Sentence: Lotte 6 Hyundai 2
#   FP: 6
#   FN: Lotte
# Sentence: Hyundai 6 Lotte 5
#   FP: 6
#   FN: Lotte
# Sentence: Haitai 2 Samsung 0
#   FN: Samsung
# Sentence: Samsung 10 Haitai 3
#   FN: Haitai
#   FN: Samsung
# Sentence: Hanwha 6 Ssangbangwool 5
#   FP: 6
#   FN: Hanwha
#   FN: Ssangbangwool
# Sentence: Note - Lotte and Hyundai , Haitai and Samsung played two games .
#   FP: two
#   FN: Lotte
# Sentence: Haitai 64 2 43 .596 -
#   FP: 64 2 43
# Sentence: Ssangbangwool 59 2 49 .545 5 1/2
#   FP: 5 1/2
#   FP: 59 2 49
#   FN: Ssangbangwool
# Sentence: Hanwha 58 1 49 .542 6
#   FP: 58 1 49
#   FN: Hanwha
# Sentence: Hyundai 57 5 49 .536 6 1/2
#   FP: 6 1/2
#   FP: 57 5 49
# Sentence: Samsung 49 5 56 .468 14
#   FP: 49 5
# Sentence: Lotte 46 6 54 .462 14 1/2
#   FP: 46
#   FP: 14 1/2
#   FN: Lotte
# Sentence: LG 46 5 59 .441 17
#   FP: 46 5
#   FN: LG
# Sentence: OB 42 6 62 .409 20 1/2
#   FP: 42
#   FP: 20 1/2
#   FN: OB
# Sentence: TENNIS - FRIDAY 'S RESULTS FROM THE U.S. OPEN .
#   FP: U.S.
#   FN: U.S. OPEN
# Sentence: NEW YORK 1996-08-30
#   FP: NEW YORK 1996-08-30
#   FN: NEW YORK
# Sentence: Results from the U.S. Open Tennis Championships at the National Tennis Centre on Friday ( prefix number denotes seeding ) :
#   FP: the National Tennis Centre
#   FP: Friday
#   FP: U.S.
#   FN: National Tennis Centre
#   FN: U.S. Open Tennis Championships
# Sentence: Sandrine Testud ( France ) beat Ines Gorrochategui ( Argentina ) 4-6 6-2 6-1
#   FP: 6-2
#   FN: Ines Gorrochategui
# Sentence: 4 - Goran Ivanisevic ( Croatia ) beat Scott Draper ( Australia ) 6-7 ( 1-7 ) 6-3 6-4 6-4
#   FP: 6-7
#   FN: Australia
#   FN: Goran Ivanisevic
#   FN: Croatia
# Sentence: Mark Philippoussis ( Australia ) beat Andrei Olhovskiy ( Russia ) 6 - 3 6-4 6-2
#   FP: 6 - 3
# Sentence: Sjeng Schalken ( Netherlands ) beat David Rikl ( Czech Republic ) 6 - 2 6-4 6-4
#   FP: Czech
#   FN: Czech Republic
# Sentence: Guy Forget ( France ) beat 17 - Felix Mantilla ( Spain ) 6-4 7-5 6-3
#   FP: 17
# Sentence: Alexander Volkov ( Russia ) beat Mikael Tillstrom ( Sweden ) 1-6 6- 4 6-1 4-6 7-6 ( 10-8 )
#   FP: 1-6
#   FP: 10-8
#   FP: 4
# Sentence: 8 - Lindsay Davenport ( U.S. ) beat Anne-Gaelle Sidot ( France ) 6-0 6-3
#   FP: 8
#   FP: 6-0
#   FN: Lindsay Davenport
# Sentence: 4 - Conchita Martinez ( Spain ) beat Helena Sukova ( Czech Republic ) 6-4 6-3
#   FP: 4 - Conchita Martinez
#   FN: Conchita Martinez
# Sentence: Amanda Coetzer ( South Africa ) beat Irina Spirlea ( Romania ) 7-6 ( 7-5 ) 7-5
#   FP: 7-5
# Sentence: Add Men 's singles , second round 16 - Cedric Pioline ( France ) beat Roberto Carretero ( Spain ) 4-6 6 - 2 6-2 6-1 Alex Corretja ( Spain ) beat Filippo Veglio ( Switzerland ) 6-7 ( 4- 7 ) 6-4 6-4 6-0
#   FP: second
#   FP: 6
#   FP: 6-4 6-4
#   FP: 16
#   FP: 6-7
#   FN: Cedric Pioline
# Sentence: Add Women 's singles , third round Linda Wild ( U.S. ) beat Barbara Rittner ( Germany ) 6-4 4-6 7-5 Asa Carlsson ( Sweden ) beat 15 - Gabriela Sabatini ( Argentina ) 7-5 3-6 6-2
#   FP: third
#   FP: 15
#   FP: 7-5
#   FN: Asa Carlsson
#   FN: Gabriela Sabatini
# Sentence: Add Men 's singles , second round 1 - Pete Sampras ( U.S. ) beat Jiri Novak ( Czech Republic ) 6-3 1-6 6-3 4-6 6-4 Paul Haarhuis ( Netherlands ) beat Michael Tebbutt ( Australia ) 1- 6 6-2 6-2 6-3
#   FP: 1-6
#   FP: 1 - Pete Sampras
#   FP: second
#   FP: 6
#   FP: Czech
#   FN: Pete Sampras
#   FN: Czech Republic
# Sentence: Add Women 's singles , third round Lisa Raymond ( U.S. ) beat Kimberly Po ( U.S. ) 6-3 6-2
#   FP: third
# Sentence: Hendrik Dreekmann ( Germany ) beat Thomas Johansson ( Sweden )
#   FP: Hendrik Dreekmann (
#   FN: Hendrik Dreekmann
# Sentence: Petr Korda ( Czech Republic ) bat Bohdan Ulihrach ( Czech Republic ) 6-0 7-6 ( 7-5 ) 6-2
#   FP: 7-5
#   FP: Czech
#   FN: Czech Republic
#   FN: Czech Republic
# Sentence: 2 - Monica Seles ( U.S. ) beat Dally Randriantefy ( Madagascar )
#   FP: 2
#   FN: Madagascar
#   FN: Monica Seles
#   FN: Dally Randriantefy
# Sentence: Add men 's singles , second round 12 - Todd Martin ( U.S. ) beat Andrea Gaudenzi ( Italy ) 6-3 6-2 6-2 Stefan Edberg ( Sweden ) beat Bernd Karbacher ( Germany ) 3-6 6-3 6-3 1-0 retired ( leg injury )
#   FP: second
#   FP: - Todd Martin
#   FP: 12
#   FP: 3-6
#   FN: Todd Martin
# Sentence: BASEBALL - MAJOR LEAGUE STANDINGS AFTER THURSDAY 'S GAMES .
#   FN: MAJOR LEAGUE
# Sentence: NEW YORK 1996-08-30
#   FP: NEW YORK 1996-08-30
#   FN: NEW YORK
# Sentence: NEW YORK 74 59 .556 -
#   FP: 74 59
#   FN: NEW YORK
# Sentence: BALTIMORE 70 63 .526 4
#   FP: 70 63
#   FN: BALTIMORE
# Sentence: BOSTON 69 65 .515 5 1/2
#   FP: 5 1/2
#   FP: 69 65
# Sentence: TORONTO 63 71 .470 11 1/2
#   FP: 63 71
#   FP: 11 1/2
#   FN: TORONTO
# Sentence: DETROIT 48 86 .358 26 1/2
#   FP: 26 1/2
#   FP: 48 86
# Sentence: CENTRAL DIVISION
#   FN: CENTRAL DIVISION
# Sentence: CLEVELAND 80 53 .602 -
#   FP: 80 53
# Sentence: CHICAGO 71 64 .526 10
#   FN: CHICAGO
# Sentence: MINNESOTA 67 67 .500 13 1/2
#   FP: 13 1/2
# Sentence: MILWAUKEE 64 71 .474 17
#   FP: 64 71
#   FN: MILWAUKEE
# Sentence: KANSAS CITY 61 74 .452 20
#   FP: KANSAS
#   FP: 61 74
#   FN: KANSAS CITY
# Sentence: WESTERN DIVISION
#   FN: WESTERN DIVISION
# Sentence: TEXAS 75 58 .564 -
#   FP: 75 58
# Sentence: SEATTLE 70 63 .526 5
#   FP: 70 63
#   FN: SEATTLE
# Sentence: OAKLAND 64 72 .471 12 1/2
#   FP: 64 72
#   FP: 12 1/2
#   FN: OAKLAND
# Sentence: CALIFORNIA 62 72 .463 13 1/2
#   FP: 62 72
#   FP: 13 1/2
# Sentence: KANSAS CITY AT DETROIT
#   FN: KANSAS CITY
#   FN: DETROIT
# Sentence: CHICAGO AT TORONTO
#   FN: CHICAGO
#   FN: TORONTO
# Sentence: MINNESOTA AT MILWAUKEE
#   FN: MILWAUKEE
# Sentence: CLEVELAND AT TEXAS
#   FN: TEXAS
# Sentence: BOSTON AT OAKLAND
#   FN: OAKLAND
# Sentence: BALTIMORE AT SEATTLE
#   FN: BALTIMORE
#   FN: SEATTLE
# Sentence: ATLANTA 83 49 .629 -
#   FP: 83 49
#   FN: ATLANTA
# Sentence: MONTREAL 71 61 .538 12
#   FP: 71 61
# Sentence: FLORIDA 64 70 .478 20
#   FN: FLORIDA
# Sentence: NEW YORK 59 75 .440 25
#   FP: 59 75
#   FN: NEW YORK
# Sentence: PHILADELPHIA 54 80 .403 30
#   FP: 54 80
# Sentence: CENTRAL DIVISION
#   FN: CENTRAL DIVISION
# Sentence: HOUSTON 72 63 .533 -
#   FP: 63
#   FN: HOUSTON
# Sentence: ST LOUIS 69 65 .515 2 1/2
#   FP: 2 1/2
#   FN: ST LOUIS
# Sentence: CINCINNATI 66 67 .496 5
#   FN: CINCINNATI
# Sentence: CHICAGO 65 66 .496 5
#   FP: 65 66
#   FN: CHICAGO
# Sentence: WESTERN DIVISION
#   FN: WESTERN DIVISION
# Sentence: SAN DIEGO 75 60 .556 -
#   FP: 75 60
# Sentence: SAN FRANCISCO 57 74 .435 16
#   FP: 57 74
#   FN: SAN FRANCISCO
# Sentence: ATLANTA AT CHICAGO
#   FN: ATLANTA
#   FN: CHICAGO
# Sentence: FLORIDA AT CINCINNATI
#   FN: FLORIDA
#   FN: CINCINNATI
# Sentence: SAN DIEGO AT MONTREAL
#   FN: MONTREAL
# Sentence: HOUSTON AT PITTSBURGH
#   FN: PITTSBURGH
#   FN: HOUSTON
# Sentence: SAN FRANCISCO AT NEW YORK
#   FN: SAN FRANCISCO
#   FN: NEW YORK
# Sentence: BASEBALL - MAJOR LEAGUE RESULTS THURSDAY .
#   FN: MAJOR LEAGUE
# Sentence: NEW YORK 1996-08-30
#   FP: NEW YORK 1996-08-30
#   FN: NEW YORK
# Sentence: DETROIT 4 Kansas City 1
#   FN: Kansas City
# Sentence: Minnesota 6 MILWAUKEE 1
#   FP: 6
#   FN: MILWAUKEE
# Sentence: CALIFORNIA 14 New York 3
#   FP: 3
#   FN: New York
# Sentence: SEATTLE 9 Baltimore 6
#   FN: SEATTLE
#   FN: Baltimore
# Sentence: San Diego 3 NEW YORK 2
#   FN: San Diego
#   FN: NEW YORK
# Sentence: Chicago 4 HOUSTON 3
#   FN: HOUSTON
# Sentence: Cincinnati 18 COLORADO 7
#   FP: 18
#   FN: COLORADO
# Sentence: Atlanta 5 PITTSBURGH 1
#   FN: PITTSBURGH
# Sentence: Los Angeles 2 MONTREAL 1
#   FP: 2
#   FN: MONTREAL
# Sentence: Florida 10 ST LOUIS 9
#   FN: ST LOUIS
# Sentence: TENNIS - TARANGO , O'BRIEN SPRING TWIN UPSETS UNDER THE LIGHTS .
#   FN: O'BRIEN
#   FN: TARANGO
# Sentence: NEW YORK 1996-08-30
#   FP: NEW YORK 1996-08-30
#   FN: NEW YORK
# Sentence: Andre Agassi escaped disaster on Thursday but Wimbledon finalist MaliVai Washington and Marcelo Rios were not so fortunate on a night of upsets at the U.S. Open .
#   FP: the U.S. Open
#   FP: Thursday
#   FP: a night
#   FN: U.S. Open
# Sentence: The 11th-seeded Washington fell short of reprising his Wimbledon miracle comeback as he lost to red-hot wildcard Alex O'Brien 6-3 6-4 5-7 3-6 6-3 in a two hour 51 minute struggle on the Stadium court .
#   FP: 51 minute
#   FP: Wimbledon
#   FP: Alex O'Brien
#   FP: the Stadium
#   FP: two hour
#   FP: 3-6 6-3

# %% [markdown]
# most of the FP are number related entities (dates, time, numbers etc.)

# %% [markdown]
# Now, use the insights from your error analysis to improve the automated prediction that you implemented in Problem&nbsp;2. While the best way to do this would be to [update spaCy&rsquo;s NER model](https://spacy.io/usage/linguistic-features#updating) using domain-specific training data, for this lab it suffices to write code to post-process the output produced by spaCy. To filter out specific labels it is useful to know the named entity label scheme, which can be found in the [model's documentation](https://spacy.io/models/en#en_core_web_sm). You should be able to improve the F1 score from Problem&nbsp;2 by at last 15 percentage points.

# %%
df = df_dev 
spans_dev_gold = set(gold_spans(df))
data = set()
for i in df.drop_duplicates('sentence_id').itertuples():
    doc = nlp(i.sentence)
    for ent in doc.ents:
        if ent.label_ not in ["CARDINAL", "DATE", "MONEY", "ORDINAL", "PERCENT", "QUANTITY", "TIME"]:
            data.add((i.sentence_id, ent.start, ent.end))

# %%
evaluation_report(spans_dev_gold, data)
# Out:
# precision: 0.8334364048649763 , recall:  0.683285448707115 , f1:  0.7509286775631501

# %%
error_report(df, spans_dev_gold, data)
# Out:
# Sentence: CRICKET - LEICESTERSHIRE TAKE OVER AT TOP AFTER INNINGS VICTORY .
#   FN: LEICESTERSHIRE
# Sentence: West Indian all-rounder Phil Simmons took four for 38 on Friday as Leicestershire beat Somerset by an innings and 39 runs in two days to take over at the head of the county championship .
#   FN: Somerset
# Sentence: Essex , however , look certain to regain their top spot after Nasser Hussain and Peter Such gave them a firm grip on their match against Yorkshire at Headingley .
#   FN: Headingley
# Sentence: Hussain , considered surplus to England 's one-day requirements , struck 158 , his first championship century of the season , as Essex reached 372 and took a first innings lead of 82 .
#   FN: Hussain
# Sentence: By the close Yorkshire had turned that into a 37-run advantage but off-spinner Such had scuttled their hopes , taking four for 24 in 48 balls and leaving them hanging on 119 for five and praying for rain .
#   FN: Such
# Sentence: At the Oval , Surrey captain Chris Lewis , another man dumped by England , continued to silence his critics as he followed his four for 45 on Thursday with 80 not out on Friday in the match against Warwickshire .
#   FN: Oval
# Sentence: Derbyshire kept up the hunt for their first championship title since 1936 by reducing Worcestershire to 133 for five in their second innings , still 100 runs away from avoiding an innings defeat .
#   FN: Derbyshire
# Sentence: Australian Tom Moody took six for 82 but Chris Adams , 123 , and Tim O'Gorman , 109 , took Derbyshire to 471 and a first innings lead of 233 .
#   FP: Australian Tom Moody
#   FN: Tom Moody
#   FN: Australian
# Sentence: They were held up by a gritty 84 from Paul Johnson but ex-England fast bowler Martin McCague took four for 55 .
#   FN: ex-England
# Sentence: CRICKET - ENGLISH COUNTY CHAMPIONSHIP SCORES .
#   FP: CRICKET - ENGLISH COUNTY CHAMPIONSHIP SCORES
#   FN: ENGLISH COUNTY CHAMPIONSHIP
# Sentence: Leicester : Leicestershire beat Somerset by an innings and 39 runs .
#   FN: Leicester
#   FN: Somerset
# Sentence: Somerset 83 and 174 ( P. Simmons 4-38 ) , Leicestershire 296 .
#   FP: Leicestershire 296
#   FN: Somerset
#   FN: Leicestershire
#   FN: P. Simmons
# Sentence: Leicestershire 22 points , Somerset 4 .
#   FP: Somerset 4
#   FN: Somerset
#   FN: Leicestershire
# Sentence: Chester-le-Street : Glamorgan 259 and 207 ( A. Dale 69 , H. Morris 69 ; D. Blenkiron 4-43 ) , Durham 114 ( S. Watkin 4-28 ) and 81-3 .
#   FP: 81-3
#   FP: A. Dale 69
#   FP: Durham 114
#   FP: S. Watkin 4-28
#   FP: H. Morris 69
#   FP: D.
#   FN: D. Blenkiron
#   FN: Chester-le-Street
#   FN: Glamorgan
#   FN: A. Dale
#   FN: Durham
#   FN: H. Morris
#   FN: S. Watkin
# Sentence: Tunbridge Wells : Nottinghamshire 214 ( P. Johnson 84 ; M. McCague 4-55 ) , Kent 108-3 .
#   FP: Kent 108-3
#   FP: M. McCague 4-55
#   FN: Kent
#   FN: Nottinghamshire
#   FN: M. McCague
#   FN: P. Johnson
# Sentence: London ( The Oval ) : Warwickshire 195 , Surrey 429-7 ( C. Lewis 80 not out , M. Butcher 70 , G. Kersey 63 , J. Ratcliffe 63 , D. Bicknell 55 ) .
#   FP: J. Ratcliffe 63
#   FP: D. Bicknell 55
#   FP: G. Kersey 63
#   FP: M. Butcher 70
#   FP: Surrey 429-7
#   FP: C. Lewis 80
#   FN: J. Ratcliffe
#   FN: Warwickshire
#   FN: G. Kersey
#   FN: D. Bicknell
#   FN: The Oval
#   FN: Surrey
#   FN: C. Lewis
#   FN: M. Butcher
# Sentence: Hove : Sussex 363 ( W. Athey 111 , V. Drakes 52 ; I. Austin 4-37 ) , Lancashire 197-8 ( W. Hegg 54 )
#   FP: Lancashire 197-8
#   FP: I. Austin 4-37
#   FN: I. Austin
#   FN: W. Athey
#   FN: Lancashire
#   FN: W. Hegg
#   FN: Sussex
#   FN: Hove
# Sentence: Portsmouth : Middlesex 199 and 426 ( J. Pooley 111 , M. Ramprakash 108 , M. Gatting 83 ) , Hampshire 232 and 109-5 .
#   FP: J. Pooley 111
#   FP: M. Gatting 83
#   FP: M. Ramprakash 108
#   FN: M. Gatting
#   FN: Portsmouth
#   FN: J. Pooley
#   FN: M. Ramprakash
# Sentence: Chesterfield : Worcestershire 238 and 133-5 , Derbyshire 471 ( J. Adams 123 , T.O'Gorman 109 not out , K. Barnett 87 ; T. Moody 6-82 )
#   FP: K. Barnett 87
#   FP: T. Moody 6-82
#   FP: Derbyshire 471
#   FP: J. Adams 123
#   FN: T.O'Gorman
#   FN: J. Adams
#   FN: K. Barnett
#   FN: T. Moody
#   FN: Chesterfield
#   FN: Worcestershire
#   FN: Derbyshire
# Sentence: Bristol : Gloucestershire 183 and 185-6 ( J. Russell 56 not out ) , Northamptonshire 190 ( K. Curran 52 ; A. Smith 5-68 ) .
#   FP: J. Russell 56
#   FP: A. Smith 5-68
#   FN: Northamptonshire
#   FN: J. Russell
#   FN: K. Curran
#   FN: A. Smith
#   FN: Gloucestershire
# Sentence: CRICKET - 1997 ASHES INTINERARY .
#   FN: ASHES
# Sentence: starting on May 13 next year , the Test and County Cricket Board
#   FP: County Cricket Board
#   FN: Test and County Cricket Board
# Sentence: English county sides and another against British Universities ,
#   FP: English county
#   FN: English
# Sentence: as well as one-day matches against the Minor Counties and
#   FN: Minor Counties
# Sentence: May 14 Practice at Lord 's
#   FN: Lord 's
# Sentence: May 15 v Duke of Norfolk 's XI ( at Arundel )
#   FP: Norfolk
#   FN: Duke of Norfolk 's XI
# Sentence: May 17 v Northampton
#   FN: Northampton
# Sentence: May 18 v Worcestershire
#   FN: Worcestershire
# Sentence: May 20 v Durham
#   FN: Durham
# Sentence: Leeds )
#   FN: Leeds
# Sentence: May 24 Second one-day international ( at The Oval ,
#   FN: The Oval
# Sentence: May 27-29 v Gloucestershire or Sussex or Surrey ( three
#   FN: Gloucestershire
# Sentence: May 31 - June 2 v Derbyshire ( three days )
#   FN: Derbyshire
# Sentence: June 14-16 v Leicestershire ( three days )
#   FN: Leicestershire
# Sentence: June 19-23 Second test ( at Lord 's )
#   FN: Lord 's
# Sentence: June 25-27 v British Universities ( at Oxford , three days )
#   FP: v British Universities
#   FN: British Universities
# Sentence: June 28-30 v Hampshire ( three days )
#   FN: Hampshire
# Sentence: July 9 v Minor Counties XI
#   FN: Minor Counties XI
# Sentence: July 12 v Scotland
#   FN: Scotland
# Sentence: July 16-18 v Glamorgan ( three days )
#   FN: Glamorgan
# Sentence: July 19-21 v Middlesex ( three days )
#   FN: Middlesex
# Sentence: August 1-4 v Somerset ( four days )
#   FN: Somerset
# Sentence: August 16-18 v Kent ( three days )
#   FN: Kent
# Sentence: SOCCER - SHEARER NAMED AS ENGLAND CAPTAIN .
#   FP: SOCCER - SHEARER NAMED AS ENGLAND CAPTAIN
#   FN: SHEARER
#   FN: ENGLAND
# Sentence: " I 'm sure there wo n't be a problem , I 'm sure Alan is the man for the job , " Hoddle said .
#   FN: Hoddle
# Sentence: SOCCER - ROMANIA BEAT LITHUANIA IN UNDER-21 MATCH .
#   FP: SOCCER - ROMANIA BEAT LITHUANIA
#   FN: ROMANIA
#   FN: LITHUANIA
# Sentence: BUCHAREST 1996-08-30
#   FN: BUCHAREST
# Sentence: Romania beat Lithuania 2-1 ( halftime 1-1 ) in their European under-21 soccer match on Friday .
#   FP: 1-1
#   FP: Lithuania 2-1
#   FN: Lithuania
# Sentence: Romania - Cosmin Contra ( 31st ) , Mihai Tararache ( 75th )
#   FN: Cosmin Contra
# Sentence: Lithuania - Danius Gleveckas ( 13rd )
#   FN: Danius Gleveckas
# Sentence: SOCCER - ROTOR FANS LOCKED OUT AFTER VOLGOGRAD VIOLENCE .
#   FP: SOCCER - ROTOR FANS LOCKED OUT AFTER
#   FN: ROTOR
#   FN: VOLGOGRAD
# Sentence: MOSCOW 1996-08-30
#   FN: MOSCOW
# Sentence: Rotor Volgograd must play their next home game behind closed doors after fans hurled bottles and stones at Dynamo Moscow players during a 1-0 home defeat on Saturday that ended Rotor 's brief spell as league leaders .
#   FP: Volgograd
#   FN: Rotor Volgograd
# Sentence: The head of the Russian league 's disciplinary committee , Anatoly Gorokhovsky , said on Friday that Rotor would play Lada Togliatti to empty stands on September 3 .
#   FN: Rotor
# Sentence: Despite the defeat , Rotor are well placed with 11 games to play in the championship .
#   FN: Rotor
# Sentence: BOXING - PANAMA 'S ROBERTO DURAN FIGHTS THE SANDS OF TIME .
#   FP: BOXING - PANAMA 'S
#   FN: PANAMA
#   FN: ROBERTO DURAN
# Sentence: PANAMA CITY 1996-08-30
#   FP: PANAMA CITY 1996-08-30
#   FN: PANAMA CITY
# Sentence: Panamanian boxing legend Roberto " Hands of Stone " Duran climbs into the ring on Saturday in another age-defying attempt to sustain his long career .
#   FP: Duran
#   FP: Roberto " Hands of Stone "
#   FN: Roberto " Hands of Stone " Duran
# Sentence: The fight , Duran 's first on home soil for 10 years , is being billed here as the " Return of the Legend " and Duran still talks as if he was in his prime .
#   FN: Return of the Legend
# Sentence: If he loses Saturday , it could devalue his position as one of the world 's great boxers , " Panamanian Boxing Association President Ramon Manzanares said .
#   FP: Panamanian Boxing Association
#   FN: Panamanian
#   FN: Boxing Association
# Sentence: Duran , whose 97-12 record spans three decades , hopes a win in the 10-round bout will earn him a rematch against Puerto Rico 's Hector " Macho " Camacho .
#   FP: Puerto Rico 's
#   FN: Hector " Macho " Camacho
#   FN: Puerto Rico
# Sentence: SQUASH - HONG KONG OPEN QUARTER-FINAL RESULTS .
#   FP: SQUASH - HONG KONG OPEN QUARTER-FINAL RESULTS
#   FN: HONG KONG OPEN
# Sentence: Quarter-final results in the Hong Kong Open on Friday ( prefix number denotes seeding ) : 1 - Jansher Khan ( Pakistan ) beat Mark Cairns ( England ) 15-10 15-6 15-7
#   FP: 1 - Jansher Khan
#   FN: Jansher Khan
#   FN: Hong Kong Open
# Sentence: 4 - Peter Nicol ( Scotland ) beat 7 - Chris Walker ( England ) 15-8 15-13 13-15 15-9
#   FN: Chris Walker
# Sentence: 2 - Rodney Eyles ( Australia ) beat Derek Ryan ( Ireland ) 15-6 15-9 11-15 15-10 .
#   FN: Rodney Eyles
#   FN: Australia
# Sentence: SOCCER - RESULTS OF SOUTH KOREAN PRO-SOCCER GAMES .
#   FN: SOUTH KOREAN
# Sentence: Pohang 3 Ulsan 2 ( halftime 1-0 )
#   FP: 1-0
#   FP: Pohang 3 Ulsan 2
#   FN: Pohang
#   FN: Ulsan
# Sentence: Puchon 2 Chonbuk 1 ( halftime 1-1 )
#   FP: Puchon 2 Chonbuk 1
#   FN: Puchon
#   FN: Chonbuk
# Sentence: Puchon 3 1 0 6 1 10
#   FN: Puchon
# Sentence: Chonan 3 0 1 13 10 9
#   FN: Chonan
# Sentence: Pohang 2 1 1 11 10 7
#   FN: Pohang
# Sentence: Suwan 1 3 0 7 3 6
#   FN: Suwan
# Sentence: Ulsan 1 0 2 8 9 3
#   FN: Ulsan
# Sentence: Anyang 0 3 1 6 9 3
#   FP: Anyang 0 3
#   FN: Anyang
# Sentence: Chonnam 0 2 1 4 5 2
#   FN: Chonnam
# Sentence: Pusan 0 2 1 3 7 2
#   FN: Pusan
# Sentence: Chonbuk 0 0 3 3 7 0
#   FN: Chonbuk
# Sentence: BASEBALL - RESULTS OF S. KOREAN PROFESSIONAL GAMES .
#   FN: S. KOREAN
# Sentence: LG 2 OB 0
#   FN: LG
#   FN: OB
# Sentence: Lotte 6 Hyundai 2
#   FN: Lotte
# Sentence: Hyundai 6 Lotte 5
#   FP: 6
#   FN: Lotte
# Sentence: Haitai 2 Samsung 0
#   FN: Samsung
# Sentence: Samsung 10 Haitai 3
#   FN: Samsung
#   FN: Haitai
# Sentence: Hanwha 6 Ssangbangwool 5
#   FN: Hanwha
#   FN: Ssangbangwool
# Sentence: Note - Lotte and Hyundai , Haitai and Samsung played two games .
#   FN: Lotte
# Sentence: Ssangbangwool 59 2 49 .545 5 1/2
#   FN: Ssangbangwool
# Sentence: Hanwha 58 1 49 .542 6
#   FN: Hanwha
# Sentence: Lotte 46 6 54 .462 14 1/2
#   FN: Lotte
# Sentence: LG 46 5 59 .441 17
#   FN: LG
# Sentence: OB 42 6 62 .409 20 1/2
#   FN: OB
# Sentence: TENNIS - FRIDAY 'S RESULTS FROM THE U.S. OPEN .
#   FP: U.S.
#   FN: U.S. OPEN
# Sentence: NEW YORK 1996-08-30
#   FP: NEW YORK 1996-08-30
#   FN: NEW YORK
# Sentence: Results from the U.S. Open Tennis Championships at the National Tennis Centre on Friday ( prefix number denotes seeding ) :
#   FP: the National Tennis Centre
#   FP: U.S.
#   FN: U.S. Open Tennis Championships
#   FN: National Tennis Centre
# Sentence: Sandrine Testud ( France ) beat Ines Gorrochategui ( Argentina ) 4-6 6-2 6-1
#   FP: 6-2
#   FN: Ines Gorrochategui
# Sentence: 4 - Goran Ivanisevic ( Croatia ) beat Scott Draper ( Australia ) 6-7 ( 1-7 ) 6-3 6-4 6-4
#   FP: 6-7
#   FN: Goran Ivanisevic
#   FN: Australia
#   FN: Croatia
# Sentence: Sjeng Schalken ( Netherlands ) beat David Rikl ( Czech Republic ) 6 - 2 6-4 6-4
#   FP: Czech
#   FN: Czech Republic
# Sentence: 8 - Lindsay Davenport ( U.S. ) beat Anne-Gaelle Sidot ( France ) 6-0 6-3
#   FP: 6-0
#   FN: Lindsay Davenport
# Sentence: 4 - Conchita Martinez ( Spain ) beat Helena Sukova ( Czech Republic ) 6-4 6-3
#   FP: 4 - Conchita Martinez
#   FN: Conchita Martinez
# Sentence: Amanda Coetzer ( South Africa ) beat Irina Spirlea ( Romania ) 7-6 ( 7-5 ) 7-5
#   FP: 7-5
# Sentence: Add Men 's singles , second round 16 - Cedric Pioline ( France ) beat Roberto Carretero ( Spain ) 4-6 6 - 2 6-2 6-1 Alex Corretja ( Spain ) beat Filippo Veglio ( Switzerland ) 6-7 ( 4- 7 ) 6-4 6-4 6-0
#   FP: 6-4 6-4
#   FP: 6-7
#   FN: Cedric Pioline
# Sentence: Add Women 's singles , third round Linda Wild ( U.S. ) beat Barbara Rittner ( Germany ) 6-4 4-6 7-5 Asa Carlsson ( Sweden ) beat 15 - Gabriela Sabatini ( Argentina ) 7-5 3-6 6-2
#   FP: 7-5
#   FN: Asa Carlsson
#   FN: Gabriela Sabatini
# Sentence: Add Men 's singles , second round 1 - Pete Sampras ( U.S. ) beat Jiri Novak ( Czech Republic ) 6-3 1-6 6-3 4-6 6-4 Paul Haarhuis ( Netherlands ) beat Michael Tebbutt ( Australia ) 1- 6 6-2 6-2 6-3
#   FP: 1 - Pete Sampras
#   FP: Czech
#   FN: Czech Republic
#   FN: Pete Sampras
# Sentence: Hendrik Dreekmann ( Germany ) beat Thomas Johansson ( Sweden )
#   FP: Hendrik Dreekmann (
#   FN: Hendrik Dreekmann
# Sentence: Petr Korda ( Czech Republic ) bat Bohdan Ulihrach ( Czech Republic ) 6-0 7-6 ( 7-5 ) 6-2
#   FP: 7-5
#   FP: Czech
#   FN: Czech Republic
#   FN: Czech Republic
# Sentence: 2 - Monica Seles ( U.S. ) beat Dally Randriantefy ( Madagascar )
#   FN: Monica Seles
#   FN: Madagascar
#   FN: Dally Randriantefy
# Sentence: Add men 's singles , second round 12 - Todd Martin ( U.S. ) beat Andrea Gaudenzi ( Italy ) 6-3 6-2 6-2 Stefan Edberg ( Sweden ) beat Bernd Karbacher ( Germany ) 3-6 6-3 6-3 1-0 retired ( leg injury )
#   FP: - Todd Martin
#   FP: 3-6
#   FN: Todd Martin
# Sentence: BASEBALL - MAJOR LEAGUE STANDINGS AFTER THURSDAY 'S GAMES .
#   FN: MAJOR LEAGUE
# Sentence: NEW YORK 1996-08-30
#   FP: NEW YORK 1996-08-30
#   FN: NEW YORK
# Sentence: NEW YORK 74 59 .556 -
#   FN: NEW YORK
# Sentence: BALTIMORE 70 63 .526 4
#   FN: BALTIMORE
# Sentence: TORONTO 63 71 .470 11 1/2
#   FN: TORONTO
# Sentence: CENTRAL DIVISION
#   FN: CENTRAL DIVISION
# Sentence: CHICAGO 71 64 .526 10
#   FN: CHICAGO
# Sentence: MILWAUKEE 64 71 .474 17
#   FN: MILWAUKEE
# Sentence: KANSAS CITY 61 74 .452 20
#   FP: KANSAS
#   FN: KANSAS CITY
# Sentence: WESTERN DIVISION
#   FN: WESTERN DIVISION
# Sentence: SEATTLE 70 63 .526 5
#   FN: SEATTLE
# Sentence: OAKLAND 64 72 .471 12 1/2
#   FN: OAKLAND
# Sentence: KANSAS CITY AT DETROIT
#   FN: DETROIT
#   FN: KANSAS CITY
# Sentence: CHICAGO AT TORONTO
#   FN: CHICAGO
#   FN: TORONTO
# Sentence: MINNESOTA AT MILWAUKEE
#   FN: MILWAUKEE
# Sentence: CLEVELAND AT TEXAS
#   FN: TEXAS
# Sentence: BOSTON AT OAKLAND
#   FN: OAKLAND
# Sentence: BALTIMORE AT SEATTLE
#   FN: SEATTLE
#   FN: BALTIMORE
# Sentence: ATLANTA 83 49 .629 -
#   FN: ATLANTA
# Sentence: FLORIDA 64 70 .478 20
#   FN: FLORIDA
# Sentence: NEW YORK 59 75 .440 25
#   FN: NEW YORK
# Sentence: CENTRAL DIVISION
#   FN: CENTRAL DIVISION
# Sentence: HOUSTON 72 63 .533 -
#   FN: HOUSTON
# Sentence: ST LOUIS 69 65 .515 2 1/2
#   FN: ST LOUIS
# Sentence: CINCINNATI 66 67 .496 5
#   FN: CINCINNATI
# Sentence: CHICAGO 65 66 .496 5
#   FN: CHICAGO
# Sentence: WESTERN DIVISION
#   FN: WESTERN DIVISION
# Sentence: SAN FRANCISCO 57 74 .435 16
#   FN: SAN FRANCISCO
# Sentence: ATLANTA AT CHICAGO
#   FN: CHICAGO
#   FN: ATLANTA
# Sentence: FLORIDA AT CINCINNATI
#   FN: CINCINNATI
#   FN: FLORIDA
# Sentence: SAN DIEGO AT MONTREAL
#   FN: MONTREAL
# Sentence: HOUSTON AT PITTSBURGH
#   FN: HOUSTON
#   FN: PITTSBURGH
# Sentence: SAN FRANCISCO AT NEW YORK
#   FN: SAN FRANCISCO
#   FN: NEW YORK
# Sentence: BASEBALL - MAJOR LEAGUE RESULTS THURSDAY .
#   FN: MAJOR LEAGUE
# Sentence: NEW YORK 1996-08-30
#   FP: NEW YORK 1996-08-30
#   FN: NEW YORK
# Sentence: DETROIT 4 Kansas City 1
#   FN: Kansas City
# Sentence: Minnesota 6 MILWAUKEE 1
#   FP: 6
#   FN: MILWAUKEE
# Sentence: CALIFORNIA 14 New York 3
#   FN: New York
# Sentence: SEATTLE 9 Baltimore 6
#   FN: SEATTLE
#   FN: Baltimore
# Sentence: San Diego 3 NEW YORK 2
#   FN: San Diego
#   FN: NEW YORK
# Sentence: Chicago 4 HOUSTON 3
#   FN: HOUSTON
# Sentence: Cincinnati 18 COLORADO 7
#   FN: COLORADO
# Sentence: Atlanta 5 PITTSBURGH 1
#   FN: PITTSBURGH
# Sentence: Los Angeles 2 MONTREAL 1
#   FN: MONTREAL
# Sentence: Florida 10 ST LOUIS 9
#   FN: ST LOUIS
# Sentence: TENNIS - TARANGO , O'BRIEN SPRING TWIN UPSETS UNDER THE LIGHTS .
#   FN: TARANGO
#   FN: O'BRIEN
# Sentence: NEW YORK 1996-08-30
#   FP: NEW YORK 1996-08-30
#   FN: NEW YORK
# Sentence: Andre Agassi escaped disaster on Thursday but Wimbledon finalist MaliVai Washington and Marcelo Rios were not so fortunate on a night of upsets at the U.S. Open .
#   FP: the U.S. Open
#   FN: U.S. Open
# Sentence: The 11th-seeded Washington fell short of reprising his Wimbledon miracle comeback as he lost to red-hot wildcard Alex O'Brien 6-3 6-4 5-7 3-6 6-3 in a two hour 51 minute struggle on the Stadium court .
#   FP: the Stadium
#   FP: 3-6 6-3
# Sentence: The day programme went smoothly although sixth-seeded former champion Agassi had to wriggle out of a dangerous 3-6 0-4 hole , winning 18 of the last 19 games against India 's Leander Paes .
#   FP: 3-6
# Sentence: The fifth set stayed on serve until the sixth game , when Washington , after saving one break point with a forehand winner down the line , netted a backhand to give O'Brien a 4-2 lead .
#   FP: 4-2
# Sentence: The Texan blasted in two aces to hold serve at 5-2 and then converted his eighth match point for victory when Washington found the net with another backhand from 40-0 .
#   FP: 5-2
# Sentence: Tarango , whose Wimbledon tantrum two years ago brought him a $ 28,000 fine and suspension from this year 's tournament at the All-England Club , argued calls and taunted fans in his lively two hour , 24 minute tango with Rios on the grandstand .
#   FN: Rios
# Sentence: The match turned on the third-set tiebreaker , which the American won 7-5 much to the dismay of the spectators .
#   FP: 7-5
# Sentence: Rios did not appreciate Tarango 's antics .
#   FN: Rios
# Sentence: " He 's always complaining too much , " said Rios . "
#   FN: Rios
# Sentence: NFL AMERICAN FOOTBALL-RANDALL CUNNINGHAM RETIRES .
#   FP: NFL AMERICAN FOOTBALL-RANDALL CUNNINGHAM RETIRES
#   FN: NFL
#   FN: CUNNINGHAM
#   FN: AMERICAN FOOTBALL-RANDALL
# Sentence: Randall Cunningham , the National Football League 's all-time leading rusher as a quarterback and one of the most athletic players ever to line up over centre , retired Thursday .
#   FP: the National Football League 's
#   FN: National Football League
# Sentence: Cunningham played his entire 11-year career with the Philadelphia Eagles .
#   FP: the Philadelphia Eagles
#   FN: Philadelphia Eagles
#   FN: Cunningham
# Sentence: A three-time Pro Bowl selection , Cunningham rushed for 4,482 yards on 677 carries .
#   FN: Pro Bowl
# Sentence: GOLF - LEADING SCORES AT GREATER MILWAUKEE OPEN .
#   FN: GREATER MILWAUKEE OPEN
# Sentence: 62 Nolan Henke
#   FN: Nolan Henke
# Sentence: 65 Billy Andrade , Duffy Waldorf , Jesper Parnevik ( Sweden )
#   FP: 65 Billy Andrade
#   FN: Billy Andrade
# Sentence: GOLF - HENKE TAKES LEAD IN MILWAUKEE , WOODS MAKES PRO DEBUT .
#   FP: GOLF - HENKE TAKES
#   FN: HENKE
#   FN: WOODS
# Sentence: Henke stood two strokes ahead of Bob Estes and three up on Billy Andrade , Duffy Waldorf and Jesper Parnevik .
#   FN: Henke
# Sentence: Woods , who turned pro Tuesday after winning an unprecedented third successive U.S. Amateur Championship , almost eagled the 18th hole .
#   FN: Woods
# Sentence: Henke , who called his round a " pleasant surprise , " finished with six birdies on the final eight holes .
#   FN: Henke
# Sentence: Henke , who came within one shot of the course record set by Andrew Magee during Wednesday 's pro-am , has three career PGA Tour victories , but none since the 1993 BellSouth Classic .
#   FP: pro-am
#   FN: Henke
# Sentence: Estes , whose only win came at the 1994 Texas Open and whose best finish this year was a third-place tie at the Nortel Open in January , eagled the par-five fourth hole and added five birdies to grab sole possession of second place .
#   FP: the Nortel Open
#   FN: Estes
#   FN: Nortel Open
# Sentence: Woods was among a group of 13 players at four under , including 1993 champion Billy Mayfair , who tied for second at last week 's World Series of Golf , and former U.S. Open champ Payne Stewart .
#   FP: U.S.
#   FN: Woods
#   FN: U.S. Open
# Sentence: Phil Mickelson , the only four-time winner on the PGA Tour , skipped the tournament after winning the World Series of Golf last week .
#   FP: the PGA Tour
#   FP: the World Series of
#   FN: World Series of Golf
#   FN: PGA Tour
# Sentence: SOCCER - SILVA 'S `LOST PASSPORT ' EXCUSE NOT ENOUGH FOR FIFA .
#   FN: SILVA
# Sentence: MADRID 1996-08-30
#   FN: MADRID
# Sentence: Silva excused his absence from Brazil 's game against Russia , on Wednesday , and Saturday 's match with the Netherlands by saying he had lost his passport .
#   FN: Silva
# Sentence: ATHLETICS - MITCHELL DEFEATS BAILEY IN FRONT OF FORMER CHAMPIONS .
#   FP: ATHLETICS - MITCHELL DEFEATS
#   FN: BAILEY
#   FN: MITCHELL
# Sentence: BERLIN 1996-08-30
#   FN: BERLIN
# Sentence: American Dennis Mitchell outclassed Olympic 100 metres champion Donovan Bailey for the third time at a major post-Games meeting in front of the most experienced sprinting crowd in the world on Friday .
#   FP: American Dennis Mitchell
#   FN: American
#   FN: Dennis Mitchell
#   FN: post-Games
# Sentence: Watched by an array of former Olympic sprint champions at the Berlin grand prix meeting , Mitchell made a brilliant start in the 100 metres and held off Bailey 's strong finish to win in 10.08 seconds despite cool conditions .
#   FN: Olympic
# Sentence: Last Friday Mitchell , who finished fourth at the Atlanta Games , upstaged a trio of Olympic champions including Bailey to win the 100 in Brussels .
#   FP: the Atlanta Games
#   FN: Atlanta Games
#   FN: Olympic
# Sentence: Berlin , Brussels and Zurich all belong to the most lucrative series in the sport , the Golden Four .
#   FP: the Golden Four
#   FN: Golden Four
# Sentence: Among the crowd on Friday were Olympic 100 metres champions going back to 1948 .
#   FN: Olympic
# Sentence: They had been invited to the meeting to watch a special relay to mark the 60th anniversary of Jesse Owens 's four gold medals at the 1936 Olympics in the same Berlin stadium .
#   FP: Jesse Owens 's
#   FP: the 1936 Olympics
#   FN: Jesse Owens
#   FN: Olympics
# Sentence: ATHLETICS - BERLIN GRAND PRIX RESULTS .
#   FP: ATHLETICS - BERLIN GRAND PRIX RESULTS
#   FN: BERLIN GRAND PRIX
# Sentence: BERLIN 1996-08-30
#   FN: BERLIN
# Sentence: Leading results at the Berlin Grand Prix athletics meeting on Friday :
#   FP: the Berlin Grand Prix
#   FN: Berlin Grand Prix
# Sentence: 2. Ludmila Engquist ( Sweden ) 12.74
#   FN: Ludmila Engquist
# Sentence: 4. Brigita Bokovec ( Slovenia ) 12.92
#   FP: Brigita Bokovec ( Slovenia
#   FN: Slovenia
#   FN: Brigita Bokovec
# Sentence: 5. Leah Pells ( Canada ) 4:09.95
#   FN: Leah Pells
# Sentence: 3. Florian Schwarthoff ( Germany ) 13.36
#   FP: Florian
#   FN: Florian Schwarthoff
# Sentence: 3. Ato Boldon ( Trinidad ) 20.37
#   FN: Ato Boldon
# Sentence: 4. Geir Moen ( Norway ) 20.41
#   FN: Geir Moen
# Sentence: 1. Noureddine Morceli ( Algeria ) 3 minutes 49.09 seconds
#   FN: Noureddine Morceli
# Sentence: 4. Laban Rotich ( Kenya ) 3:53.42
#   FN: Laban Rotich
# Sentence: 7. Andreas Seelig ( Germany ) 62.00
#   FP: Seelig
#   FN: Andreas Seelig
# Sentence: 1. Gail Devers ( U.S. ) 10.89 seconds
#   FN: Gail Devers
# Sentence: 3. Gwen Torrence ( U.S. ) 11.07
#   FP: Torrence
#   FN: Gwen Torrence
# Sentence: 5. Chryste Gaines ( U.S. ) 11.20
#   FN: Chryste Gaines
# Sentence: 7. Irina Privalova ( Russia ) 11.27
#   FN: Irina Privalova
# Sentence: 2. Gete Wami ( Ethiopia ) 15:05.21
#   FN: Gete Wami
# Sentence: 1. Torrance Zellner ( U.S. ) 48.23 seconds
#   FN: Torrance Zellner
# Sentence: 5. Sven Nylander ( Sweden ) 49.22
#   FN: Sven Nylander
# Sentence: 1. Falilat Ogunkoya ( Nigeria ) 50.31 seconds
#   FP: Falilat Ogunkoya ( Nigeria
#   FN: Falilat Ogunkoya
#   FN: Nigeria
# Sentence: 2. Jearl Miles ( U.S. ) 50.42
#   FN: Jearl Miles
# Sentence: 4. Anja Ruecker ( Germany ) 51.61
#   FN: Anja Ruecker
# Sentence: 5. Olabisi Afolabi ( Nigeria ) 51.98
#   FP: Olabisi Afolabi ( Nigeria
#   FN: Olabisi Afolabi
#   FN: Nigeria
# Sentence: 5. Davidson Ezinwa ( Nigeria ) 10.24
#   FP: Davidson Ezinwa ( Nigeria
#   FN: Nigeria
#   FN: Davidson Ezinwa
# Sentence: 6. Geir Moen ( Norway ) 10.33
#   FN: Geir Moen
# Sentence: 4. Nico Motchebon ( Germany ) 1:45.03
#   FN: Nico Motchebon
# Sentence: 6. Adem Hacini ( Algeria ) 1:45.64
#   FP: Hacini ( Algeria
#   FN: Adem Hacini
#   FN: Algeria
# Sentence: 1= Andrei Tiwontschik ( Germany ) 5.86
#   FP: 1= Andrei Tiwontschik
#   FN: Andrei Tiwontschik
# Sentence: 1= Igor Trandenkov ( Russia ) 5.86
#   FP: 1= Igor Trandenkov
#   FN: Igor Trandenkov
# Sentence: 1. Stefka Kostadinova ( Bulgaria ) 2.03
#   FP: Kostadinova
#   FN: Stefka Kostadinova
# Sentence: 3. Alina Astafei ( Germany ) 1.97
#   FP: Astafei
#   FP: Alina
#   FN: Alina Astafei
# Sentence: 6= Nele Zilinskiene ( Lithuania ) 1.91
#   FP: 6= Nele Zilinskiene
#   FN: Nele Zilinskiene
# Sentence: 5. Armen Martirosyan ( Armenia ) 16.57
#   FN: Armen Martirosyan
# Sentence: 6. Sigurd Njerve ( Norway ) 16.41
#   FN: Sigurd Njerve
# Sentence: 1. Tanja Damaske ( Germany ) 66.60 metres
#   FP: Damaske
#   FN: Tanja Damaske
# Sentence: 7. Natalya Shikolen ( Belarus ) 60.74
#   FP: Natalya
#   FN: Natalya Shikolen
# Sentence: ( Nigeria ) , Davidson Ezinwa ( Nigeria ) 38.87
#   FP: Davidson Ezinwa ( Nigeria
#   FN: Davidson Ezinwa
#   FN: Nigeria
# Sentence: SOCCER - THREE STANDARD LIEGE PLAYERS BANNED , CLUB FINED .
#   FP: CLUB FINED
#   FN: STANDARD LIEGE
# Sentence: GENEVA 1996-08-30
#   FN: GENEVA
# Sentence: UEFA came down heavily on Belgian club Standard Liege on Friday for " disgraceful behaviour " in an Intertoto final match against Karlsruhe of Germany .
#   FP: Karlsruhe of Germany
#   FN: Karlsruhe
#   FN: Germany
#   FN: Intertoto
# Sentence: The Belgian club were fined 25,000 Swiss francs ( $ 20,850 ) for unsporting conduct and captain Guy Hellers banned for seven games .
#   FN: Swiss
# Sentence: Roberto Bisconti will be sidelined for six Euro ties after pushing the referee in the back as he protested about a Karlsruhe goal , while Didier Ernst was banned for four matches for a verbal attack soon after Bisconti was also dismissed .
#   FN: Euro
# Sentence: Karlsruhe won the August 20 match 3-1 thanks to two late goals .
#   FP: 3-1
# Sentence: They took the tie 3-2 on aggregate and qualified for the UEFA Cup .
#   FP: the UEFA Cup
#   FP: 3-2
#   FN: UEFA Cup
# Sentence: ATHLETICS - HARRISON , EDWARDS TO MEET IN SARAJEVO .
#   FP: ATHLETICS - HARRISON
#   FN: HARRISON
#   FN: SARAJEVO
# Sentence: MONTE CARLO 1996-08-30
#   FP: MONTE CARLO 1996-08-30
#   FN: MONTE CARLO
# Sentence: Olympic champion Kenny Harrison and world record holder Jonathan Edwards will both take part in a triple jump competition at the Solidarity Meeting for Sarajevo on September 9 .
#   FP: the Solidarity Meeting for Sarajevo
#   FN: Solidarity Meeting for Sarajevo
#   FN: Olympic
# Sentence: The International Amateur Athletic Federation said on Friday that a schedule reshuffle had allowed organisers to hold a men 's triple jump as well as the women 's long jump on the " one usable runway at the war-devastated " Kosevo stadium .
#   FP: The International Amateur Athletic Federation
#   FN: International Amateur Athletic Federation
# Sentence: Atlanta Games silver medal winner Edwards has called on other leading athletes to take part in the Sarajevo meeting -- a goodwill gesture towards Bosnia as it recovers from the war in the Balkans -- two days after the grand prix final in Milan .
#   FP: Atlanta
#   FN: Atlanta Games
# Sentence: Edwards was quoted as saying : " What type of character do we show by going to the IAAF Grand Prix Final in Milan where there is a lot of money to make but refusing to make the trip to Sarajevo as a humanitarian gesture ? "
#   FP: the IAAF Grand Prix Final
#   FN: IAAF Grand Prix Final
# Sentence: SOCCER - BARATELLI TO COACH NICE .
#   FN: NICE
#   FN: BARATELLI
# Sentence: Baratelli , who played for Nice and Paris St Germain , takes over from Albert Emon who was fired on Thursday after Nice 's home defeat to Guingamp 2-1 in the league .
#   FP: Guingamp 2-1
#   FP: Paris
#   FN: Paris St Germain
#   FN: Guingamp
#   FN: Baratelli
# Sentence: Nice have been unable to win any of their four league matches played this season and are lying a lowly 18th in the table .
#   FN: Nice
# Sentence: SOCCER - MILAN 'S LENTINI MOVES TO ATALANTA .
#   FN: MILAN
#   FN: LENTINI
#   FN: ATALANTA
# Sentence: Former Italian international winger Gianluigi Lentini , transferred to Milan in 1992 for what was believed to be a world record sum , has been loaned to serie A club Atalanta for a year , newspapers reported on Friday .
#   FP: serie A club Atalanta
#   FN: serie A
#   FN: Atalanta
# Sentence: The Gazzetta dello Sport said the deal would cost Atalanta around $ 600,000 .
#   FP: Gazzetta
#   FN: Gazzetta dello Sport
# Sentence: Lentini , 27 , joined Milan from Torino in a $ 12 million deal that many have speculated involved far more money changing hands and which has subsequently been investigated by magistrates for alleged financial irregularities .
#   FN: Lentini
# Sentence: The move to Bergamo-based Atalanta reunites Lentini , who fell out with ex-Milan coach Fabio Capello last season , with his former coach at Torino , Emiliano Mondonico .
#   FN: Bergamo-based
# Sentence: CRICKET - SRI LANKA BEAT AUSTRALIA BY FOUR WICKETS .
#   FN: SRI LANKA
#   FN: AUSTRALIA
# Sentence: Sri Lanka beat Australia by four wickets in the third match of the Singer World Series one-day ( 50 overs ) cricket tournament on Friday .
#   FP: the Singer World Series
#   FN: Singer World Series
# Sentence: Scores : Australia 228-9 in 50 overs , Sri Lanka 232-6 in 45.5 overs .
#   FP: Sri Lanka 232-6
#   FN: Australia
#   FN: Sri Lanka
# Sentence: CRICKET - AUSTRALIA V SRI LANKA SCOREBOARD .
#   FP: V SRI LANKA SCOREBOARD
#   FN: AUSTRALIA
#   FN: SRI LANKA
# Sentence: M. Waugh c and b Jayasuriya 50
#   FN: Jayasuriya
#   FN: M. Waugh
# Sentence: S. Law c Tillekeratne b Dharmasena 13
#   FP: S. Law c Tillekeratne b Dharmasena 13
#   FN: Dharmasena
#   FN: Tillekeratne
#   FN: S. Law
# Sentence: M. Bevan c Vaas b Chandana 56
#   FP: M. Bevan c Vaas b
#   FN: M. Bevan
#   FN: Vaas
#   FN: Chandana
# Sentence: S. Waugh b Muralitharan 22
#   FP: S. Waugh b
#   FN: Muralitharan
#   FN: S. Waugh
# Sentence: D. Lehmann st Kaluwitharana b Chandana 2
#   FN: Chandana
#   FN: Kaluwitharana
# Sentence: I. Healy c Ranatunga b Muralitharan 8
#   FP: Ranatunga b Muralitharan 8
#   FN: Muralitharan
#   FN: Ranatunga
# Sentence: J. Gillespie st Kaluwitharana b Chandana 6
#   FP: J. Gillespie st Kaluwitharana b
#   FN: Kaluwitharana
#   FN: Chandana
#   FN: J. Gillespie
# Sentence: D. Fleming c Chandana b Jayasuriya 3
#   FP: Chandana b Jayasuriya
#   FN: Chandana
#   FN: Jayasuriya
# Sentence: Bowling : Vass 7-0-29-0 , de Silva 4-0-25-0 , Dharmasena
#   FP: Vass 7-0-29-0
#   FN: Vass
#   FN: de Silva
# Sentence: 9-0-49-1 , Muralitharan 10-0-41-2 , Jayasuriya 10-0-43-2 , Chandana
#   FP: Jayasuriya 10-0-43-2
#   FN: Muralitharan
#   FN: Jayasuriya
#   FN: Chandana
# Sentence: S. Jayasuriya c Healy b Fleming 44
#   FN: Healy
#   FN: Fleming
# Sentence: R. Kaluwitharana b S. Waugh 8
#   FP: R. Kaluwitharana b S. Waugh 8
#   FN: S. Waugh
#   FN: R. Kaluwitharana
# Sentence: A.de Silva not out 83
#   FN: A.de Silva
# Sentence: A. Ranatunga lbw b Fleming 0
#   FP: A. Ranatunga lbw
#   FN: A. Ranatunga
#   FN: Fleming
# Sentence: H. Tillekeratne lbw b Fleming 1
#   FP: H. Tillekeratne lbw
#   FN: H. Tillekeratne
#   FN: Fleming
# Sentence: R. Mahanama b McGrath 50
#   FP: R. Mahanama b McGrath
#   FN: McGrath
#   FN: R. Mahanama
# Sentence: Bowling : S. Waugh 5-1-36-1 , Law 2-0-23-0 , McGrath 9.5-0-44-1 ,
#   FP: McGrath 9.5-0-44-1
#   FN: Law
#   FN: S. Waugh
#   FN: McGrath
# Sentence: Fleming 8-1-26-3 , Gillespie 6-0-27-0 , M. Waugh 5-0-29-0 , Lehmann
#   FP: Gillespie 6-0-27-0
#   FP: M. Waugh 5-0-29-0
#   FN: M. Waugh
#   FN: Fleming
#   FN: Gillespie
# Sentence: 6-0-26-0 , Bevan 4-0-18-0 .
#   FP: Bevan 4-0-18-0 .
#   FN: Bevan
# Sentence: CRICKET - AUSTRALIA 228-9 IN 50 OVERS V SRI LANKA .
#   FP: V SRI LANKA
#   FN: AUSTRALIA
#   FN: SRI LANKA
# Sentence: Australia scored 228 for nine wickets in their 50 overs against Sri Lanka in the third day-night limited overs match of the Singer World Series tournament on Friday .
#   FP: the Singer World Series
#   FN: Singer World Series
# Sentence: CRICKET - AUSTRALIA WIN TOSS AND CHOOSE TO BAT .
#   FN: AUSTRALIA
# Sentence: overs cricket match in the Singer world series tournament on
#   FP: overs cricket match
#   FN: Singer
# Sentence: Australia - Ian Healy ( captain ) , Michael Bevan , Damien Flemming , Jason Gillespie , Stuart Law , Glenn McGrath , Ricky Ponting , Michael Slater , Darren Lehmann , Mark Waugh , Steve Waugh .
#   FN: Ian Healy
# Sentence: Sri Lanka - Arjuna Ranatunga ( captain ) , Sanath Jayasuriya ,
#   FP: Ranatunga
#   FP: Sri Lanka - Arjuna
#   FN: Sri Lanka
#   FN: Arjuna Ranatunga
# Sentence: ROMANIA COMELF H1 PROFIT RISE BELOW TARGET .
#   FP: H1 PROFIT RISE
#   FN: COMELF
# Sentence: BUCHAREST 1996-08-30
#   FN: BUCHAREST
# Sentence: Romanian listed state engineer Comelf said it almost doubled six-month output , with net profit rising by 33 percent to 1.069 billion lei .
#   FN: Comelf
# Sentence: Comelf 's six-month output rose to 4,378 tonnes of equipment from 2,684 tonnes in the equivalent period in 1995 , the company report to the Bucharest stock exchange showed .
#   FN: Comelf
# Sentence: Comelf , based in the central Transylvanian town of Bistrita , manufactures water purification equipment , machinery for the thermal power sector and other equipment .
#   FN: Comelf
# Sentence: From January to June Comelf exported 59 percent of its output , up from 37.3 percent in the same period last year .
#   FN: Comelf
# Sentence: -- Luli Popescu , Bucharest Newsroom 40-1 3120264
#   FP: -- Luli Popescu ,
#   FN: Bucharest Newsroom
#   FN: Luli Popescu
# Sentence: POLISH NBP REFRAINS FROM REVERSE REPO OPERATION .
#   FP: POLISH NBP
#   FN: POLISH
# Sentence: WARSAW 1996-08-30
#   FN: WARSAW
# Sentence: The National Bank of Poland
#   FP: The National Bank of Poland
#   FN: National Bank of Poland
# Sentence: -- Warsaw Newsroom +48 22 653 9700
#   FP: Warsaw Newsroom +48
#   FN: Warsaw Newsroom
# Sentence: The government of Canada 's cash balances fell in the week that ended August 28 , the Bank of Canada said on Friday .
#   FP: the Bank of Canada
#   FN: Bank of Canada
# Sentence: Treasury bills 152.80 +0.300 - 11.900
#   FP: +0.300
# Sentence: Jones Medical completes acquisition .
#   FN: Jones Medical
# Sentence: ST. LOUIS 1996-08-30
#   FN: ST. LOUIS
# Sentence: NEW YORK 1996-08-30
#   FP: NEW YORK 1996-08-30
#   FN: NEW YORK
# Sentence: NYMEX refined product prices lingered at session lows amid slim volume before the close while crude experienced lackluster buying ahead of the U.S. Labor Day weekend , traders said .
#   FP: NYMEX
#   FN: Labor Day
# Sentence: Buying interest in crude did not have enough conviction to send it much higher since many players had left early to start the Labor Day holiday weekend , traders said .
#   FN: Labor Day
# Sentence: NYMEX will be closed Monday due to Labor Day .
#   FP: NYMEX
#   FN: Labor Day
# Sentence: -- Harry Milling , New York Energy Desk , +1 212-859-1761
#   FP: -- Harry Milling
#   FN: Harry Milling
# Sentence: U.S. debt futures end lower , shaken by Chicago NAPM .
#   FN: NAPM
# Sentence: CHICAGO 1996-08-30
#   FN: CHICAGO
# Sentence: U.S. debt futures finished a shortened pre-holiday session sharply lower , as the markets were shaken by a stronger than expected rise in the August National Association of Purchasing Management ( NAPM ) index for the Chicago area , traders and analysts said .
#   FP: the August National Association of Purchasing Management
#   FN: National Association of Purchasing Management
# Sentence: Primary dealers immediately sold Eurodollar and bond futures , after the market on average was expecting the index to rise marginally to 51.9 from July 's 51.2 .
#   FN: Eurodollar
# Sentence: Traders also said Japanese investors were unwinding long Eurodollar futures / short swaps , and that heavy put buying helped pressure Eurodollars to lower levels before the close .
#   FN: Eurodollar
#   FN: Eurodollars
# Sentence: Rumors circulated that the Federal Reserve was buying five-year notes , and that a renowned hedge fund manager was buying 10-year notes in the cash markets .
#   FP: the Federal Reserve
#   FN: Federal Reserve
# Sentence: While the market continues to price-in higher U.S. interest rates , there was little conviction to the theory that the Federal Reserve would tighten rates before the next Federal Open Market Committee meeting on September 24 .
#   FP: price-in
#   FP: the Federal Reserve
#   FN: Federal Reserve
# Sentence: Earlier in the day , Fed chairman Alan Greenspan said at the annual Jackson Hole symposium that the goal of price stability is within reach for major nations .
#   FP: Jackson Hole
#   FN: Jackson Hole symposium
# Sentence: Traders said the Fed 's decision to adopt a tightening bias at the July FOMC meeting has cast more focus on every piece of U.S. economic news .
#   FN: FOMC
# Sentence: At the end of pit trade , December bonds were off 27/32 at 106-25/32 , 10-year notes down 21/32 at 105-17/32 , munibonds off 17/32 at 111-20/32 , December Eurodollars were down 11 bps at 93.94 , March Eurodollars were off 13 bps at 93.72 and March T-bills were down 12 bps at 94.33 .
#   FN: Eurodollars
# Sentence: Magna was up 1/8 to 48-1/4 on the New York Stock Exchange .
#   FP: the New York Stock Exchange
#   FN: Magna
#   FN: New York Stock Exchange
# Sentence: The acquisition will beef up Markham , Ontario-based Magna 's North American car and truck seating business , allowing it to better compete with Johnson Controls Inc and Lear Corp .
#   FN: Ontario-based
#   FN: Magna
# Sentence: He added that Douglas & Lomason 's top executives have been asked to stay on with Magna after the merger , though their future roles have not yet been defined .
#   FP: Douglas & Lomason 's
#   FN: Douglas & Lomason
#   FN: Magna
# Sentence: Douglas & Lomason 's profits were hurt in the past year by model changeovers , which had reduced production at some important customers , but are now recovering , analysts said .
#   FP: Douglas & Lomason 's
#   FN: Douglas & Lomason
# Sentence: It should give Magna the critical mass to be a bigger player in that market . "
#   FN: Magna
# Sentence: Magna 's traditional strength has been instrument panels , door panels and other interior components .
#   FN: Magna
# Sentence: Magna , Johnson Controls and Lear have been working to build up their capabilties to supply complete interiors to automakers , including seats , instrument panels , door panels carpeting and headliners .
#   FN: Magna
# Sentence: -- Jim Ballantyne , London Newsroom +44 171 542 8062
#   FP: London Newsroom +44
#   FP: -- Jim Ballantyne
#   FN: London Newsroom
#   FN: Jim Ballantyne
# Sentence: Police said the seven men , who freed all their hostages after the plane landed at Stansted airport on Tuesday and then appealed for asylum , would appear in court on Saturday .
#   FN: Stansted
# Sentence: GERMANY - Bunds extended losses , flirting with session lows after falling victim to sharply higher U.S. economic data which revived fears that interest rates may soon turn higher .
#   FP: GERMANY - Bunds
#   FN: GERMANY
# Sentence: The September Bund future on the London International Financial Futures and Options Exchange ( LIFFE ) was trading at 97.18 , down 0.20 from Thursday 's settlement price .
#   FP: the London International Financial Futures and Options Exchange
#   FN: London International Financial Futures and Options Exchange
# Sentence: A sharp plunge in U.S. Treasuries after a shock rise in the Chicago PMI pulled gilts lower , but traders said the market was nervous anyway ahead of August MO data and the PMI survey due on Monday .
#   FP: MO
#   FP: U.S.
#   FP: Chicago
#   FP: PMI
#   FN: Chicago PMI
#   FN: U.S. Treasuries
# Sentence: The September notional bond future on the MATIF in Paris settled at 123.14 , up 0.04 from Thursday 's settlement price .
#   FP: MATIF
# Sentence: ITALY - Bond futures held to easier levels in late afternoon after the sharp drop in Treasuries , but a resilient lira helped limit BTP losses .
#   FP: BTP
#   FN: Treasuries
#   FN: ITALY
# Sentence: UNITED STATES - Prices of U.S. Treasury securities were trading sharply lower near midday after a surprisingly strong Chicago Purchasing Managers ' report shook the markets ahead of the long Labour Day weekend .
#   FP: Chicago Purchasing Managers '
#   FP: UNITED STATES - Prices
#   FN: Labour Day
#   FN: UNITED STATES
#   FN: Chicago Purchasing Managers
# Sentence: The September Treasury bond future on the Chicago Board of Trade was trading at 107-11/32 , down 26/32 from Thursday 's settlement price .
#   FP: The September Treasury
#   FP: the Chicago Board of Trade
#   FN: Treasury
#   FN: Chicago Board of Trade
# Sentence: Japanese Goverment Bonds futures which closed before the output data , lost much of day 's gains as Tokyo stock prices recovered from the day 's low.In after hours trading the September future on LIFFE was trading at 122.53 , up 0.26 from Thursday 's settlement price on the Tokyo Stock Exchange .
#   FP: the Tokyo Stock Exchange
#   FP: Japanese
#   FN: Japanese Goverment Bonds
#   FN: Tokyo Stock Exchange
# Sentence: EUROBONDS - Primary market activity was sharply lower , as players wound down ahead of Monday 's U.S. Labour Day holiday and next week 's U.S. employment data .
#   FP: U.S. Labour Day
#   FN: U.S.
#   FN: Labour Day
#   FN: EUROBONDS
# Sentence: NSW Treasury launched a A$ 100 million three-year discount bond aimed at Japanese investors .
#   FN: A$
# Sentence: DNIB issued a 275 million Norwegian crown bond , which was pre-placed with a European institution .
#   FN: DNIB
# Sentence: DNIB also set a 110 million guilder step-up bond .
#   FN: DNIB
# Sentence: Boxing-Bruno quits on doctor 's advice .
#   FN: Boxing-Bruno
# Sentence: An eye specialist told the 35-year-old Bruno that he could be blinded in one eye if he boxed again , the newspaper said .
#   FN: Bruno
# Sentence: Bruno , for years one of Britain 's most popular sportsmen , had hoped to have another shot at the world title and had been in training until a routine eye test on Monday highlighted a problem with his right eye .
#   FN: Bruno
# Sentence: Bruno lost three world title fights before finally landing the crown by beating American Oliver McCall in a unanimous points decision at Wembley in September 1995 .
#   FP: American Oliver McCall
#   FN: American
#   FN: Bruno
#   FN: Oliver McCall
# Sentence: But Bruno lost the title on his first defence when he fought American Tyson in Las Vegas .
#   FN: Tyson
# Sentence: Soccer - McCarthy names team to play Liechtenstein .
#   FP: Soccer - McCarthy
#   FN: McCarthy
# Sentence: DUBLIN 1996-08-30
#   FN: DUBLIN
# Sentence: Birmingham 's Gary Breen was selected ahead of Phil Babb in defence , while 18-year-old Ian Harte makes his international competitive debut .
#   FP: 18-year-old Ian Harte
#   FN: Ian Harte
# Sentence: Given , Breen , Staunton , Irwin , McAteer , Harte , McLoughlin , Houghton , Townsend , Quinn , O'Neill .
#   FN: Given
# Sentence: LAGOS 1996-08-30
#   FN: LAGOS
# Sentence: A gang of thieves in eastern Nigeria paid a police corporal to carry off eight air conditioners they had just stolen , the national news agency reported on Friday .
#   FP: the national news agency
# Sentence: " Little did I know I was dealing with robbers , " the News Agency of Nigeria quoted the unnamed corporal as saying .
#   FP: the News Agency of Nigeria
#   FN: News Agency of Nigeria
# Sentence: East Dries miners fail to report for work .
#   FN: East Dries
# Sentence: JOHANNESBURG 1996-08-30
#   FN: JOHANNESBURG
# Sentence: Workers at Driefontein Consolidated Ltd 's east gold mine have failed to report for work since Wednesday night , mine managers Gold Fields of South Africa Ltd said on Friday .
#   FP: Driefontein Consolidated Ltd 's
#   FN: Driefontein Consolidated Ltd
# Sentence: At least 17 miners have been killed in labour unrest -- sparked by ethnic differences -- at Driefontein Consolidated and Gold Fields ' Kloof Gold Mining Co this month .
#   FP: Driefontein Consolidated
#   FP: Gold Fields '
#   FN: Driefontein Consolidated and Gold Fields ' Kloof Gold Mining Co
# Sentence: Chad government closes university after protests .
#   FN: Chad
# Sentence: The government of Chad has closed N'Djamena University after two days of protests over grant arrears in which Education Minister Nagoum Yamassoum was held hostage for four hours , state radio said on Friday .
#   FP: Education
# Sentence: Yeltsin endorses Lebed Chechnya peace plan - agency .
#   FP: Lebed Chechnya
#   FN: Chechnya
#   FN: Lebed
# Sentence: MOSCOW 1996-08-30
#   FN: MOSCOW
# Sentence: Russian Prime Minister Viktor Chernomyrdin said on Friday that President Boris Yeltsin , who is vacationing outside Moscow , had backed security chief Alexander Lebed 's peace plan for Chechnya , Interfax news agency said .
#   FP: Alexander Lebed 's
#   FN: Alexander Lebed
# Sentence: " Lebed is now in Chechnya solving some problems , " Interfax quoted Chernomyrdin as saying . "
#   FP: Interfax quoted Chernomyrdin
#   FN: Interfax
#   FN: Chernomyrdin
#   FN: Lebed
# Sentence: Moscow , which wants to keep Chechnya as a part of the Russian Federation , sent troops to the region in December 1994 to quell its independence bid .
#   FP: the Russian Federation
#   FN: Russian Federation
# Sentence: Itar-Tass news agency quoted Lebed as saying that he would suggest to the rebels that the decision on Chechnya 's future political status be deferred by up to 10 years .
#   FP: Itar-Tass news agency
#   FN: Itar-Tass
# Sentence: Lebed , Chechens sign framework political deal .
#   FN: Chechens
# Sentence: " We just now signed a statement and attached the basic principles of relations between the Russian Federation and the Chechen Republic , " Lebed told reporters after he and Maskhadov signed a package of documents .
#   FP: the Russian Federation
#   FP: the Chechen Republic
#   FN: Chechen Republic
#   FN: Russian Federation
# Sentence: SARAJEVO 1996-08-30
#   FN: SARAJEVO
# Sentence: The Bosnian government radio broadcast said U.S. Assistant Secretary of State John Kornblum had reassured SDA officials , including presumably its leader , Bosnian President Alija Izetbegovic , whom he met during a Friday visit .
#   FP: State
# Sentence: The Party of Democratic Action ( SDA ) had called on Wednesday for its followers abroad to boycott the absentee balloting because of voter registration irregularities , especially among Serb refugees .
#   FP: The Party of Democratic Action
#   FN: Party of Democratic Action
# Sentence: The Organisation for Security and Cooperation in Europe ( OSCE ) postponed municipal elections as a result of the irregularities but decided to proceed with voting for higher offices .
#   FP: The Organisation for Security and Cooperation in Europe
#   FN: Organisation for Security and Cooperation in Europe
# Sentence: The SDA , joined by two other parties , has been demanding that OSCE prohibit refugees voting from any place other than their pre-war place of residence as a means to prevent the elections from ratifying the results of ethnic cleansing .
#   FN: OSCE
# Sentence: " During the works , all flights will be re-routed to the nearby airport in Batajnica , with no change in schedules , " Tanjug quotes Belgrade airport General Director Ljubomir Acimovic as saying .
#   FN: Tanjug
# Sentence: The Batajnica airport will take over complete air traffic control during this period , Federal Air Traffic Control Administration Director Branko Bilbija said .
#   FN: Batajnica
# Sentence: -- Amra Kevic , Belgrade newsroom +381 11 2224305
#   FP: -- Amra Kevic
#   FN: Amra Kevic
# Sentence: A senior Belarus politician accused President Alexander Lukashenko on Friday of attempting to set up a dictatorship in the former Soviet republic .
#   FP: Soviet republic
#   FN: Soviet
# Sentence: Lukashenko , 41 , won presidential polls in 1994 on promises to restore order , fight corruption and repair the strong links with Russia that were disrupted by the collapse of the Soviet Union .
#   FP: the Soviet Union
#   FN: Soviet Union
# Sentence: The United States last week granted political asylum to two opposition leaders , Zenon Poznyak and Sergei Naumchik .
#   FP: The United States
#   FN: United States
# Sentence: Tajik troops now control devastated town .
#   FN: Tajik
# Sentence: Tajik government troops now control of the strategically vital town of Tavildara after driving out Islamic rebels , but sporadic gunfire still echoed in the nearby Pamir mountains on Friday .
#   FP: Pamir mountains
#   FN: Pamir
#   FN: Tajik
# Sentence: Sherbatov said the rebels were located about three km ( two miles ) east of Tavildara around the village of Layron .
#   FN: Sherbatov
# Sentence: WARSAW 1996-08-30
#   FN: WARSAW
# ...
#   FP: Aung San Suu
#   FN: Aung San Suu Kyi
# Sentence: In May the government launched a sweeping crackdown on the democracy movement , detaining over 260 members of Suu Kyi 's National League for Democracy ( NLD ) ahead of a party congress .
#   FP: congress
#   FP: Suu Kyi 's
#   FN: Suu Kyi
# Sentence: The Burmese government last week confirmed the recent sentencing of nine democracy activists who were arrested in the May crackdown , including Suu Kyi 's assistant Win Htein .
#   FP: Suu Kyi 's
#   FN: Suu Kyi
# Sentence: But Suu Kyi disagreed with the methods , saying officials often arrested NLD supporters in the middle of the night , then did not give them the opportunity to defend themselves in trials .
#   FN: Suu Kyi
# Sentence: The NLD party won a landslide victory in a 1990 election but the State Law and Order Restoration Council ( SLORC ) , which assumed power in 1988 after crushing pro-democracy demonstrations , never recognised the poll .
#   FP: The NLD party
#   FP: the State Law and Order Restoration Council
#   FN: State Law and Order Restoration Council
#   FN: NLD
# Sentence: Hla Than , an elected member of parliament for the NLD , died in early August after being at Insein for six years .
#   FP: Insein for
#   FN: Hla Than
#   FN: Insein
# Sentence: His death came five weeks after James Leander ( Leo ) Nichols , a close friend of Suu Kyi and Danish honorary consul , died while serving a prison term at Insein .
#   FP: James Leander
#   FP: Nichols
#   FP: Leo
#   FN: James Leander ( Leo ) Nichols
# Sentence: The Dow Chemical Co of the United States will invest $ 4 billion to build an ethylene plant in Tianjin city in northern China , the China Daily said on Saturday .
#   FP: the United States
#   FP: The Dow Chemical Co
#   FP: the China Daily
#   FN: United States
#   FN: Dow Chemical Co
#   FN: China Daily
# Sentence: North Korea demanded on Saturday that South Korea return a northern war veteran who has been in the South since the 1950-53 war , Seoul 's unification ministry said .
#   FP: unification ministry
# Sentence: Kim , an unrepentant communist , was captured during the Korean War and released after spending more than 30 years in a southern jail .
#   FP: the Korean War
#   FN: Korean
# Sentence: He submitted a petition to the International Red Cross in 1993 asking for his repatriation .
#   FP: the International Red Cross
#   FN: International Red Cross
# Sentence: The domestic Yonhap news agency said the South Korean government would consider the northern demand only if the North accepted Seoul 's requests , which include regular reunions of families split by the Korean War .
#   FP: the Korean War
#   FN: Korean
# Sentence: Chinese police have detained veteran dissident Wang Donghai , the New York-based pressure group Human Rights in China said on Saturday .
#   FP: Human Rights
#   FP: China
#   FN: Human Rights in China
# Sentence: The group demanded Wang 's release and said his detention was a dangerous signal China was returning to its Cultural Revolution days .
#   FP: Cultural Revolution days
#   FN: Cultural Revolution
# Sentence: Last month , Wang , 45 , a veteran dissident of the 1979 Democracy Wall movement , was ordered to serve one year of " re-education through labour " , but released because of poor health .
#   FN: Democracy Wall
# Sentence: Chinese police have detained dissident Wang Donghai , the New York-based pressure group Human Rights in China said on Saturday .
#   FP: China
#   FP: Human Rights
#   FN: Human Rights in China
# Sentence: Last month , Wang , 45 , a veteran dissident of the 1979 Democracy Wall movement , was ordered to serve one year of " re-education through labour " , but released because of poor health .
#   FN: Democracy Wall
# Sentence: " I am sorry to my ancestors for five generations , " Chen Chun-yeh told the High Court after sentencing on Friday , the Hong Kong Standard said . "
#   FP: the High Court
#   FP: the Hong Kong Standard
#   FN: High Court
#   FN: Hong Kong Standard
# Sentence: Chen , a former army secretary of the Chinese Nationalist regime which fled from mainland China to Taiwan in 1949 , pleaded guilty to trafficking 42 kg ( 92 pounds ) of drugs that could have been turned into 25 kg ( 55 pounds ) of heroin .
#   FP: Nationalist
# Sentence: Two Chinese cities are to ban the use of disposable plastic containers as part of efforts to fight pollution , the China Daily said on Saturday .
#   FP: the China Daily
#   FN: China Daily
# Sentence: Iraqi Kurds say Iranian troops enter north Iraq .
#   FP: Iraqi
#   FP: Kurds
#   FN: Iraqi Kurds
# Sentence: ISTANBUL 1996-08-31
#   FN: ISTANBUL
# Sentence: Iranian troops on Saturday entered Kurdish-controlled northern Iraq in the wake of an assault backed by Baghdad into the region , an Iraqi Kurdish group told Reuters .
#   FP: Iraqi
#   FP: Kurdish
#   FN: Kurdish-controlled
#   FN: Iraqi Kurdish
# Sentence: They have established a headquarters in Chuman , " Faik Nerweyi of the Kurdistan Democratic Party ( KDP ) told Reuters by telephone from Ankara .
#   FP: Faik Nerweyi of the Kurdistan Democratic Party
#   FN: Kurdistan Democratic Party
#   FN: Faik Nerweyi
# Sentence: The PUK accuses the KDP of collaborating with Baghdad .
#   FN: PUK
#   FN: KDP
# Sentence: Northern Iraq has been under Iraqi Kurdish control since after the 1991 Gulf War .
#   FP: the 1991 Gulf War
#   FP: Iraqi
#   FP: Kurdish
#   FN: Iraqi Kurdish
#   FN: Gulf War
# Sentence: U.S.-led allied planes based in Turkey are intended to protect the Kurds from Baghdad .
#   FP: allied
#   FN: U.S.-led
# Sentence: JERUSALEM 1996-08-31
#   FN: JERUSALEM
# Sentence: Representatives of the five nations making up the committee -- Israel , Lebanon , Syria , France and the United States -- will meet at 11 a.m. ( 0800 GMT ) in Naqoura , the coastal headquarters of the U.N. Interim Force in Lebanon ( UNIFIL ) .
#   FP: the U.N. Interim Force
#   FP: the United States
#   FP: Lebanon
#   FN: United States
#   FN: U.N. Interim Force in Lebanon
# Sentence: " The committee will meet following a complaint by Israel over an incident in which two Lebanese residents were injured by Hizbollah fire in the Sikhin village ...
#   FP: Sikhin village
#   FN: Sikhin
# Sentence: Hizbollah ( Party of God ) gunmen have waged a guerrilla war to oust Israel from the area .
#   FN: Party of God
# Sentence: KPD confirms Iraqi military aid-U.N. official .
#   FN: aid-U.N.
# Sentence: BAGHDAD 1996-08-31
#   FN: BAGHDAD
# Sentence: Kurdistan Democratic Party ( KDP ) of Massoud Barzani said that it was being backed by Iraqi heavy armour and artillery in a battle with rival Kurds for the city of Arbil , a senior U.N. official in Baghdad said .
#   FN: KDP
# Sentence: Fire destroys restaurant in Bahraini village .
#   FP: Bahraini village
#   FN: Bahraini
# Sentence: MANAMA 1996-08-31
#   FN: MANAMA
# Sentence: They said a fire broke out at Shul'ala restaurant in the early hours on Saturday in al-Daih village , five km ( three miles ) west of the capital Manama .
#   FN: Shul'ala
#   FN: al-Daih
# Sentence: BAGHDAD 1996-08-31
#   FN: BAGHDAD
# Sentence: " The leadership has decided to provide support and military aid to Mr Massoud Barzani and his comrades to enable them confront the vicious aggression ...
#   FP: Mr Massoud Barzani
#   FN: Massoud Barzani
# Sentence: from ( Patriotic Union of Kurdistan chief ) Jalal Talabani , " Aziz said in a statement carried by the official Iraqi News Agency ( INA ) .
#   FP: Kurdistan
#   FP: Patriotic Union
#   FN: Patriotic Union of Kurdistan
# Sentence: Aziz said Iraq 's military intervention , the first on such scale since the U.S. and allies decided to protect Iraqi Kurds against Baghdad , was in response to a plea from Barzani to President Saddam Hussein to back him militarily and save his people from attacks by Iran and Talabani .
#   FP: Iraqi
#   FP: Kurds
#   FN: Iraqi Kurds
# Sentence: U.N. relief officials said they were not aware that the tanks advancing on Arbil were manned by Iraqi troops as they advanced from KDP-controlled areas and raised KDP flags .
#   FN: KDP
# Sentence: BAGHDAD 1996-08-31
#   FN: BAGHDAD
# Sentence: " KDP ( Kurdistan Democratic Party ) is trying to overtake the city .
#   FP: KDP ( Kurdistan Democratic Party
#   FN: KDP
#   FN: Kurdistan Democratic Party
# Sentence: PRESS DIGEST - Tunisia - Aug 31 .
#   FN: Tunisia
# Sentence: TUNIS 1996-08-31
#   FN: TUNIS
# Sentence: LA PRESSE
#   FN: LA PRESSE
# Sentence: - Tunisia 's exports of spare parts amounted to 220 million dinars in 1995 .
#   FN: Tunisia
# Sentence: LE TEMPS
#   FN: LE TEMPS
# Sentence: - Trade talks between Tunisia and the Palestinian Authority .
#   FP: the Palestinian Authority
#   FN: Palestinian Authority
# Sentence: The first portion of the campaign involves pickup trucks equipped with billboards that were driving along some of the nation 's busiest interstate highways during the Labor Day weekend , including Interstate 95 on the East Coast , Interstates 80 and 90 in the Midwest and Interstate 5 in California .
#   FP: the East Coast
#   FN: Labor Day
#   FN: East Coast
#   FN: 90
# Sentence: Automakers petitioned the National Highway Traffic Safety Administration to allow them to introduce air bags that inflate less aggressively to help reduce unwanted injuries .
#   FP: the National Highway Traffic Safety Administration
#   FN: National Highway Traffic Safety Administration
# Sentence: ROCHESTER , N.H. 1996-08-30
#   FP: N.H. 1996-08-30
#   FN: N.H.
# Sentence: An explosion leveled Rochester 's one-story Lilac Falls Motel , killing two people , fire officials said Friday .
#   FP: Lilac Falls Motel
#   FN: Lilac Falls
# Sentence: As far as I know , it 's been to four alarms -- more trucks , more people , " said Don Penney of the Rochester Fire Department said .
#   FP: the Rochester Fire Department
#   FN: Rochester Fire Department
# Sentence: Eyewitnesses told Boston television stations they saw a gasoline truck parked behind the Lilac Falls Motel and smelled gasoline shortly before the explosion .
#   FP: the Lilac Falls Motel
#   FN: Lilac Falls Motel
# Sentence: They said 200 fighter planes , including 79 on the aircraft carrier Carl Vinson , were already in the Gulf ; the aircraft carrier Enterprise was in the eastern Mediterranean with 79 more , and an air expeditionary force with up to 40 more was ready to fly from the United States if ordered .
#   FP: the United States
#   FN: United States
#   FN: Enterprise
# Sentence: " Yesterday the president ordered the Department of Defense to take prudent planning steps to have forces ready to deploy to the region should he direct us to do so , " Pentagon spokesman Doug Kennett said . "
#   FP: the Department of Defense
#   FN: Department of Defense
# Sentence: In addition to the 158 F / A-18 , F-14 and other fighter planes on the aircraft carriers Vinson and Enterprise , the Air Force air expeditionary force of 30 to 40 F-15 and F-16 fighter planes and fuel tankers is ready to fly from three U.S. bases in the United States , they said .
#   FP: the United States
#   FN: Enterprise
#   FN: United States
# Sentence: Most of the Marines are on three ships in the Tarawa Amphibious Readiness Group .
#   FP: the Tarawa Amphibious Readiness Group
#   FN: Tarawa Amphibious Readiness Group
# Sentence: Algerian newspapers quoted the Human Rights National Observatory ( ONDH ) , a government-appointed watchdog , as saying earlier in August that about 1,400 civilians had been killed in bomb attacks blamed on Moslem guerrillas in the past two years .
#   FP: the Human Rights National Observatory
#   FN: Human Rights National Observatory
# Sentence: BONN 1996-08-31
#   FN: BONN
# Sentence: Gust was threatened with violence , then locked into a room to be interrogated on suspicion of " promoting activities hostile to the state " while his guests were taken away , the magazine said .
#   FN: Gust
# Sentence: Nyerere arrived in Rome this week on a private visit and held talks with the U.S. special envoy to Burundi , Howard Wolpe , and the Sant ' Egidio Community , an Italian Roman Catholic organisation which has been monitoring Burundi closely .
#   FP: the Sant ' Egidio Community
#   FN: Nyerere
#   FN: Sant ' Egidio Community
# Sentence: " ( Nyerere ) informed Minister Dini of the latest developments in the ( Great Lakes ) region , with particular respect to Burundi following the military coup d'etat on July 25 , " the ministry said in a statement .
#   FN: Nyerere
#   FN: Great Lakes
# Sentence: Nyerere was due to be presented with an " Artisans for Peace " prize by the Lay Volunteers ' International Organisation on Sunday .
#   FP: the Lay Volunteers ' International Organisation
#   FN: Lay Volunteers ' International Organisation
#   FN: Nyerere
# Sentence: The U.N. Security Council on Friday condemned the coup by retired Tutsi major Pierre Buyoya and for the first time said in a resolution it intended to pressure Buyoya into unconditional negotiations with all parties and factions " without exception " .
#   FP: The U.N. Security Council
#   FN: Tutsi
#   FN: U.N. Security Council
# Sentence: Nato declines comment on fighting in Iraq .
#   FP: Nato
# Sentence: The North Atlantic Treaty Organisation 's spokesman on Saturday declined all comment on reports of armed conflict in northern Iraq .
#   FP: The North Atlantic Treaty Organisation 's
#   FN: North Atlantic Treaty Organisation
# Sentence: Earlier on Saturday , an Iraqi Kurd leader said both Iraqi troops and Kurdistan Democratic Party ( KDP ) forces were attacking the city of Arbil in northern Iraq .
#   FP: Iraqi
#   FN: Iraqi Kurd
# Sentence: On Tuesday , thieves stole about 40 forearms from a shooting range in southern Belgium , including Kalashnikov , Uzi and Fal automatic weapons .
#   FN: Fal
#   FN: Uzi
# Sentence: Police declined to comment on whether it suspected a link with the Marc Dutroux case , the paedophile kidnap , sex abuse and murder scandal which has rocked Belgium in the past two weeks .
#   FN: Marc Dutroux
# Sentence: Controversial IRA film screened at Venice festival .
#   FN: IRA
# Sentence: VENICE , Italy 1996-08-31
#   FP: VENICE
# Sentence: Dublin-born director Neil Jordan says he never lost more sleep over a film than over " Michael Collins " , his controversial epic about the IRA which has its premiere on Saturday at the Venice Film Festival .
#   FP: the Venice Film Festival
#   FN: IRA
#   FN: Venice Film Festival
# Sentence: The film , starring Liam Neeson and Julia Roberts , recounts the life of Michael Collins , the Irish Republican Army 's Director of Intelligence who fought for Irish independence from 1919 to 1921 .
#   FP: the Irish Republican Army 's
#   FN: Irish Republican Army
# Sentence: Although not due for release in Britain until early next year , some politicians have already said they feared it would fan sectarian tensions in British-ruled Northern Ireland .
#   FN: British-ruled
# Sentence: Jordan , whose 1992 film " The Crying Game " also came under fire for what was perceived as a sympathetic portrayal of the IRA , said Collins was more than just a revolutionary .
#   FP: " The Crying Game "
#   FN: The Crying Game
#   FN: IRA
# Sentence: " Collins would never be a proponent of contemporary terrorism as practised today .
#   FN: Collins
# Sentence: Leeson , the Northern Ireland-born actor who was nominated for an Oscar for best actor for his performance in " Schindler 's List " , plays the lead role in Jordan 's film .
#   FP: Northern
#   FN: Northern Ireland-born
# Sentence: " I have never lost more sleep over the making of a film than I have over ' Michael Collins ' , but I 'll never make a more important one , " Jordan said .
#   FP: Michael Collins '
#   FN: Michael Collins
# Sentence: Dhaka stocks seen steady in absence of big players .
#   FN: Dhaka
# Sentence: DHAKA 1996-08-31
#   FN: DHAKA
# Sentence: Shares on the Dhaka Stock Exchange ( DSE ) may remain steady as small investors are expected to target mainly blue chips while overseas investors will prefer to keep to the sidelines when the market reopens after Moslem Friday weekend , brokers said .
#   FP: the Dhaka Stock Exchange
#   FN: Dhaka Stock Exchange
# Sentence: Brokers said blue chips like IDLC , Bangladesh Lamps , Chittagong Cement and Atlas Bangladesh were expected to rise .
#   FN: Atlas Bangladesh
# Sentence: -- Dhaka Newsroom 880-2-506363
#   FN: Dhaka Newsroom

# %% [markdown]
# Show that you achieve the performance goal by reporting the evaluation measures that you implemented in Problem&nbsp;1.

# %% [markdown]
# Before going on, we ask you to store the outputs of the improved named entity recognizer on the development data in a new data frame. This new frame should have the same layout as the original data frame for the development data that you loaded above, but should contain the *predicted* start and end positions for each token span, rather than the gold positions. As the `label` of each span, you can use the special value `--NME--`.

# %%
import pandas as pd

df = df_dev 
spans_dev_gold = set(gold_spans(df))
data = set()
for i in df.drop_duplicates('sentence_id').itertuples():
    doc = nlp(i.sentence)
    for ent in doc.ents:
        if ent.label_ not in ["CARDINAL", "DATE", "MONEY", "ORDINAL", "PERCENT", "QUANTITY", "TIME"]:
            data.add((i.sentence_id, i.sentence, ent.start, ent.end, "--NME--"))

df_dev_2 = pd.DataFrame(list(data), columns = ["sentence_id", "sentence", "beg", "end", "label"])

# %% [markdown]
# ## Problem 4: Entity linking

# %% [markdown]
# Now that we have a method for predicting mention spans, we turn to the task of **entity linking**, which amounts to predicting the knowledge base entity that is referenced by a given mention. In our case, for each span we want to predict the Wikipedia page that this mention references.
#
# Start by extending the generator function that you implemented in Problem&nbsp;2 to labelled spans.

# %%
def gold_mentions(df):
    """Yield the gold-standard mentions in a data frame.

    Args:
        df: A data frame.

    Yields:
        The gold-standard mention spans in the specified data frame as
        quadruples consisting of the sentence id, start position, end
        position and entity label of each span.
    """
    # TODO: Replace the next line with your own code
    for i in df.itertuples():
        yield (i.sentence_id, i.beg, i.end, i.label)
        
spans_dev_gold = set(gold_mentions(df_dev))

# %% [markdown]
# A naive baseline for entity linking on our data set is to link each mention span to the Wikipedia page name that we get when we join the tokens in the span by underscores, as is standard in Wikipedia page names. Suppose, for example, that a span contains the two tokens
#
#     Jimi Hendrix
#
# The baseline Wikipedia page name for this span would be
#
#     Jimi_Hendrix
#
# Implement this naive baseline and evaluate its performance. Print the evaluation measures that you implemented in Problem&nbsp;1.

# %% [markdown]
# **Here and in the remainder of this lab, you should base your entity predictions on the predicted spans that you computed in Problem&nbsp;3.**

# %%
data = set()
for i ,row in df_dev_2.iterrows():
    words = row.sentence.split()
    data.add((row.sentence_id, row.beg, row.end, "_".join(words[row.beg:row.end])))

# %%
evaluation_report(spans_dev_gold, data)
# Out:
# precision: 0.3141620284477427 , recall:  0.2575629541997634 , f1:  0.28306092124814264

# %% [markdown]
# ## Problem 5: Extending the training data using the knowledge base

# %% [markdown]
# State-of-the-art approaches to entity linking exploit information in knowledge bases. In our case, where Wikipedia is the knowledge base, one particularly useful type of information are links to other Wikipedia pages. In particular, we can interpret the anchor texts (the highlighted texts that you click on) as mentions of the entities (pages) that they link to. This allows us to harvest long lists of mention–entity pairings.
#
# The following cell loads a data frame summarizing anchor texts and page references harvested from the first paragraphs of the English Wikipedia. The data frame also contains all entity mentions in the training data (but not the development or the test data).

# %%
with bz2.open('kb.tsv.bz2', 'rt', encoding = 'cp850') as source:
    df_kb = pd.read_csv(source, sep='\t', quoting=csv.QUOTE_NONE)

# %% [markdown]
# To understand what information is available in this data, the following cell shows the entry for the anchor text `Sweden`.

# %%
df_kb.loc[df_kb.mention == 'Sweden']
# Out:
#       mention                                 entity      prob
# 17436  Sweden                                 Sweden  0.985768
# 17437  Sweden          Sweden_national_football_team  0.014173
# 17438  Sweden  Sweden_men's_national_ice_hockey_team  0.000059

# %% [markdown]
# As you can see, each row of the data frame contains a pair $(m, e)$ of a mention $m$ and an entity $e$, as well as the conditional probability $P(e|m)$ for mention $m$ referring to entity $e$. These probabilities were estimated based on the frequencies of mention–entity pairs in the knowledge base. The example shows that the anchor text &lsquo;Sweden&rsquo; is most often used to refer to the entity [Sweden](http://en.wikipedia.org/wiki/Sweden), but in a few cases also to refer to Sweden&rsquo;s national football and ice hockey teams. Note that references are sorted in decreasing order of probability, so that the most probable pairing come first.
#
# Implement an entity linking method that resolves each mention to the most probable entity in the data frame. If the mention is not included in the data frame, you can predict the generic label `--NME--`. Print the precision, recall, and F1 of your method using the function that you implemented for Problem&nbsp;1.

# %%
dat = set()
for i in data:
    df_filt = df_kb.loc[df_kb.mention == i[3]]
    if df_filt.shape[0] != 0: 
         dat.add((i[0],i[1],i[2],df_filt.iloc[0,1]))
    else:
         dat.add((i[0],i[1],i[2], "--NME--"))

# %%
evaluation_report(spans_dev_gold, dat)
# Out:
# precision: 0.4850546279117708 , recall:  0.3976677370288998 , f1:  0.43703566121842496

# %% [markdown]
# ## Problem 6: Context-sensitive disambiguation

# %% [markdown]
# Consider the entity mention &lsquo;Lincoln&rsquo;. The most probable entity for this mention turns out to be [Lincoln, Nebraska](http://en.wikipedia.org/Lincoln,_Nebraska); but in pages about American history, we would be better off to predict [Abraham Lincoln](http://en.wikipedia.org/Abraham_Lincoln). This suggests that we should try to disambiguate between different entity references based on the textual context on the page from which the mention was taken. Your task in this last problem is to implement this idea.
#
# Set up a dictionary that contains, for each mention $m$ that can refer to more than one entity $e$, a separate Naive Bayes classifier that is trained to predict the correct entity $e$, given the textual context of the mention. As the prior probabilities of the classifier, choose the probabilities $P(e|m)$ that you used in Problem&nbsp;5. To let you estimate the context-specific probabilities, we have compiled a data set with mention contexts:

# %%
with bz2.open('contexts.tsv.bz2') as source:
    df_contexts = pd.read_csv(source, sep='\t', quoting=csv.QUOTE_NONE)

# %% [markdown]
# This data frame contains, for each ambiguous mention $m$ and each knowledge base entity $e$ to which this mention can refer, up to 100 randomly selected contexts in which $m$ is used to refer to $e$. For this data, a **context** is defined as the 5 tokens to the left and the 5 tokens to the right of the mention. Here are a few examples:

# %%
df_contexts.head()
# Out:
#           mention                 entity  \
# 0            1970  UEFA_Champions_League
# 1            1970         FIFA_World_Cup
# 2  1990 World Cup    1990_FIFA_World_Cup
# 3  1990 World Cup    1990_FIFA_World_Cup
# 4  1990 World Cup    1990_FIFA_World_Cup
#
#                                              context
# 0    Cup twice the first in @ and the second in 1983
# 1  America 1975 and during the @ and 1978 World C...
# 2                 Manolo represented Spain at the @
# 3  Hašek represented Czechoslovakia at the @ and ...
# 4  renovations in 1989 for the @ The present capa...

# %% [markdown]
# Note that, in each context, the position of the mention is indicated by the `@` symbol.
#
# From this data frame, it is easy to select the data that you need to train the classifiers – the contexts and corresponding entities for all mentions. To illustrate this, the following cell shows how to select all contexts that belong to the mention &lsquo;Lincoln&rsquo;:

# %%
df_contexts.context[df_contexts.mention == 'Lincoln']
# Out:
# 41465    Nebraska Concealed Handgun Permit In @ municip...
# 41466    Lazlo restaurants are located in @ and Omaha C...
# 41467    California Washington Overland Park Kansas @ N...
# 41468    City Missouri Omaha Nebraska and @ Nebraska It...
# 41469    by Sandhills Publishing Company in @ Nebraska USA
#                                ...
# 41609                                      @ Leyton Orient
# 41610                    English division three Swansea @
# 41611    league membership narrowly edging out @ on goa...
# 41612                                          @ Cambridge
# 41613                                                   @
# Name: context, Length: 149, dtype: object

# %% [markdown]
# Implement the context-sensitive disambiguation method and evaluate its performance. Here are some more hints that may help you along the way:
#
# **Hint 1:** The prior probabilities for a Naive Bayes classifier can be specified using the `class_prior` option. You will have to provide the probabilities in the same order as the alphabetically sorted class (entity) names.
#
# **Hint 2:** Not all mentions in the knowledge base are ambiguous, and therefore not all mentions have context data. If a mention has only one possible entity, pick that one. If a mention has no entity at all, predict the `--NME--` label.

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.pipeline import Pipeline

def predict_entity(mention, sentence):
    filtered_context = df_contexts[df_contexts.mention == mention]
    X = filtered_context.context
    Y = filtered_context.entity
    priors = list(df_kb.loc[df_kb.mention == mention].sort_values("entity").prob)
    
    if filtered_context.shape[0] == 0 and len(priors) == 0:
        return "--NME--"
    elif filtered_context.shape[0] == 0 and len(priors) != 0:
        return list(df_kb.loc[df_kb.mention == mention].entity)[0]
    else: 
        model = Pipeline([('vect', CountVectorizer()), 
                            ('MNB', MultinomialNB(class_prior = priors))])

        model.fit(X = X, y = Y)

        entity = model.predict([sentence])[0]
        return entity

# %%
data = set()
for i ,row in df_dev_2.iterrows():
    words = row.sentence.split()
    mention = "_".join(words[row.beg:row.end])
    entity = predict_entity(mention, row.sentence)
    data.add((row.sentence_id, row.beg, row.end, entity))

# %%
evaluation_report(spans_dev_gold, data)
# Out:
# precision: 0.4955679241393527 , recall:  0.4062869697481832 , f1:  0.4465081723625557

# %% [markdown]
# You should expect to see a small (around 1&nbsp;unit) increase in both precision, recall, and F1.

# %% [markdown]
# ## Reflection questions

# %% [markdown]
# The following reflection questions are questions that you could be asked in the oral exam. Try to answer each of them in the form of a short text and enter it in the cell below. You will get feedback on your answers from your lab assistant.

# %% [markdown]
# **RQ 5.1:** In Problem&nbsp;3, you did an error analysis on the task of recognizing text spans mentioning named entities. Summarize your results. Pick one type of error that you observed. How could you improve the model&rsquo;s performance on this type of error? What resources (such as domain knowledge, data, compute) would you need to implement this improvement?
#
# We can see that geographical names are not predicted. Well we used Spacy for predictions, it looks like spacy is not trained on geographical names and this could be solved by training it. Domain knowledge as a list of geographical names would be necessary.
#
# **RQ 5.2:** Thinking back about Problem&nbsp;6, explain what the word *context* refers to in the task addressed there, and how context can help to disambiguate between different entities. Suggest other types of context that you could use for disambiguation.
#
# context is a sentence where the entity is contained. What this context does is enabling us to decide what entity matches best the sentence we are predicting on. We also base this context consideration on the mention this sentence is related to. As a context we could also use POS tagging.
#
#
#
# **RQ 5.3:** One type of entity mentions that we did not cover explicitly in this lab are pronouns. As an example, consider the sentence pair *Ruth Bader Ginsburg was an American jurist*. *She served as an associate justice of the Supreme Court from 1993 until her death in 2020*. What facts would you want to extract from this sentence pair? How do pronouns make fact extraction hard?
#
# - Ruth Bader Ginsburg - American jurist
# - Ruth Bader Ginsburg - served as an associate justice of the Supreme Court from 1993
# - Ruth Bader Ginsburg - death in 2020
#
# because in seperate sentences we dont know to whom pronouns are referring. when the name is stated expicitly we are sure that what is being said is about the subject and otherwise when we have pronouns its more diffcult to identify the subject

# %% [markdown]
# **This was the last lab in the Text Mining course. Congratulations! 🥳**
